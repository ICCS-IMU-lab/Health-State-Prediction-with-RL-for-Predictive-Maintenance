# %% [markdown]
# ## CNC Mill Wear Prediction Using Reinforcement Learning and Data from PHM 2010

# %%
pip install torch torchvision torchaudio

# %%
import torch

if torch.cuda.is_available():
    print("CUDA is available! Using GPU.")
else:
    print("CUDA is not available. Using CPU.")

# %%
pip install stable-baselines3[extra]

# %%
pip install gymnasium

# %%
# Helper Libraries
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd
import os
import torch
import time

# Environment Building
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete

# RL Algorithms
import stable_baselines3
from stable_baselines3 import PPO
from stable_baselines3 import A2C
from stable_baselines3 import DDPG
from stable_baselines3 import SAC

from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.results_plotter import plot_results, X_TIMESTEPS
from stable_baselines3.common.monitor import Monitor

from pathlib import Path

# %%
file_paths_cnc = "./normalised_time_domain_features_with_cut_and_flute_max.csv"
df = pd.read_csv(file_paths_cnc)
print(df.head())

# %%
# Global Parameters for CNC Custom Env

MAX_STEPS = len(df.loc[:, 'File'].values) #len = 315

MAX_DIFF = 6

REW_WEIGHT = [0.1 , 0.1 , 0.1 , 0.7] # flute_1-2-3 and flute_max

time_domain_features_columns = ['dyn_X_mean', 'dyn_X_rms', 'dyn_X_crest', 'dyn_X_avg_power', 'dyn_X_skewness', 'dyn_X_kurtosis', 'dyn_Y_mean', 'dyn_Y_rms', 'dyn_Y_crest', 'dyn_Y_avg_power', 'dyn_Y_skewness', 'dyn_Y_kurtosis', 'dyn_Z_mean', 'dyn_Z_rms', 'dyn_Z_crest', 'dyn_Z_avg_power', 'dyn_Z_skewness', 'dyn_Z_kurtosis', 'acc_X_mean', 'acc_X_rms', 'acc_X_crest', 'acc_X_avg_power', 'acc_X_skewness', 'acc_X_kurtosis', 'acc_Y_mean', 'acc_Y_rms', 'acc_Y_crest', 'acc_Y_avg_power', 'acc_Y_skewness', 'acc_Y_kurtosis', 'acc_Z_mean', 'acc_Z_rms', 'acc_Z_crest', 'acc_Z_avg_power', 'acc_Z_skewness', 'acc_Z_kurtosis', 'AE_mean', 'AE_rms', 'AE_crest', 'AE_avg_power', 'AE_skewness', 'AE_kurtosis']
flute_wear_collumns = ['flute_1','flute_2', 'flute_3', 'flute_max']

# %%
''''class CNC_Env_Non_Corrective_Pred(gymnasium.Env):

    def __init__(self, df):

        self.df = df
        self.reward_range = (np.NINF , 1 ) # Πρέπει να ορίσω το εύρος των rewards

        # Define the low and high bounds for each dimension of the action space
        low_bound = np.array([0, 0, 0], dtype=np.float64)
        high_bound = np.array([1, 1, 1], dtype=np.float64)

        # Action Space
        self.action_space = gymnasium.spaces.Box(low=low_bound, high=high_bound, dtype=np.float64)

        # Observation Space | Είναι κανονικοποιημένο από 0-1 | 7 sensors * 6 time domain features = 42
        self.observation_space = gymnasium.spaces.Box(low=0, high=1, shape=(42,), dtype=np.float64)

        # Ξεκινάω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

    def _state_s0(self):
        # βάλε randomness εδώ
        self.current_step = 0
        # flute_1 = df[] diff bettwen d[1] - d[0] * (random val (0,2))
        # state_0 - ( state_1 - state_0)
        self.flute_1 = (2*self.df.loc[0, "flute_1"]) - self.df.loc[1, "flute_1"]
        self.flute_2 = (2*self.df.loc[0, "flute_2"]) - self.df.loc[1, "flute_2"]
        self.flute_3 =  (2*self.df.loc[0, "flute_3"]) - self.df.loc[1, "flute_3"]
        self.flute_max = (2*self.df.loc[0, "flute_max"]) - self.df.loc[1, "flute_max"]

        # Θέτουμε και τα predictions στην αρχική κατάσταση του συστήματος
        self.flute_1_pred = self.flute_1
        self.flute_2_pred = self.flute_2
        self.flute_3_pred = self.flute_3
        self.flute_max_pred = max(self.flute_1 , self.flute_2 , self.flute_3)

        self.pred_dif_1 = 0
        self.pred_dif_2 = 0
        self.pred_dif_3 = 0
        self.pred_dif_max = 0

    # Constructing Observations From Environment States
    def _get_obs(self):

        # Παίρνω τα time domain features του current (δηλαδή του αντίστοιχου cut)
        frame = self.df.loc[self.current_step, time_domain_features_columns].to_numpy(dtype=np.float64)

        # Φτιαχνω το observation
        obs = frame

        return obs

    def _get_info(self):
        return {
            "cut": self.current_step
        }

    def _take_action(self, action):

        # Βρες την διαφορά μεταξύ της προηγούμενης τιμής και της εκτιμόμενης τιμής

        # Action Space Example : array([0.79758393, 0.41074004, 0.0026002 ])

        # Αν θέλουμε μετά από κάθε state Sn να κάνουμε ένα Predict βάση του σωστού Sn-1
        #self.flute_1_pred = self.flute_1 + (action[0] * MAX_DIFF)
        #self.flute_2_pred = self.flute_2 + (action[1] * MAX_DIFF)
        #self.flute_3_pred = self.flute_3 + (action[2] * MAX_DIFF)
        #self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        ## Σε κάθε state Sn κάνουμε Predict βάση της προηγούμενης πρόβλεψης Sn-1
        #print("Before : ", self.flute_1_pred)
        # φθορα στο μυτακι 1 (ν) = φθορα στο μυτακι 1 πρβλεπομενη(ν-1) + prediction του agent
        # Prediction του agent = 100% max diff φθορων σε καταστασεις χρησεις του μηχανηματος (ν -> ν+1)
        self.flute_1_pred += (action[0] * MAX_DIFF)
        #print("After : ", self.flute_1_pred)
        self.flute_2_pred += (action[1] * MAX_DIFF)
        self.flute_3_pred += (action[2] * MAX_DIFF)
        self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        self.flute_1 = self.df.loc[self.current_step, "flute_1"]
        self.flute_2 = self.df.loc[self.current_step, "flute_2"]
        self.flute_3 = self.df.loc[self.current_step, "flute_3"]
        self.flute_max = self.df.loc[self.current_step, "flute_max"]

        # Η διαφορά μεταξύ της προβλεπόμενης τιμής και της κανονικής τιμής
        self.pred_dif_1 = self.flute_1_pred - self.flute_1
        self.pred_dif_2 = self.flute_1_pred - self.flute_1
        self.pred_dif_3 = self.flute_1_pred - self.flute_1
        self.pred_dif_max = self.flute_max_pred - self.flute_max

    def reset(self, seed = None, options = None):
        #We need the following line to seed self.np_random
        super().reset(seed=seed)

        # Επιστρέφω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

        # Set the current step to the start of the dataset
        self.current_step = 0

        observation = self._get_obs()
        info = self._get_info()

        return observation,info

    def score_function(self,delta):
        if delta < 0:
            return 1 - np.exp(-delta/10)
        else:
            return  1 - np.exp(delta/4.5)

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        # Παραμετροποιεί το reward έτσι ώστε να ενισχύει τις δράσεις που προσφέρουν οφέλοι σε μέλλοντα χρόνο
        #delay_modifier = (self.current_step / MAX_STEPS)

        reward_flute_1 = self.score_function(self.pred_dif_1)
        reward_flute_2 = self.score_function(self.pred_dif_2)
        reward_flute_3 = self.score_function(self.pred_dif_3)
        reward_flute_max = self.score_function(self.pred_dif_max)

        reward = (REW_WEIGHT[0]*reward_flute_1) + (REW_WEIGHT[1]*reward_flute_2) + (REW_WEIGHT[2]*reward_flute_3) + (REW_WEIGHT[3]*reward_flute_max)
        #reward = reward * delay_modifier
        #print("Reward : " ,reward)
        # Ελέγχουμε εάν πάμε να βγούμε εκτός του dataset
        terminated = False
        if self.current_step > MAX_STEPS - 2:
            # τότε πρέπει να κάνουμε reset
            terminated = True  #διαλέγω terminated καθώς είναι φυσιολογική η λήξη

        observation = self._get_obs()
        info = self._get_info()

        #Εδω μπορούμε να βάλουμε κάποιο όριο απόκλισης τιμών στις προβλέψεις ώστε να κάνουμε την μάθηση ταχύτερη
        trunctated = False # Ελέγχουμε εάν υπάρχει κάποιο condition εξωτερικό του περιβάλλοντος πχ. Όριο χρόνου
        if reward < -5000 :
          trunctated = True

        return observation, reward, terminated,trunctated, info

    metadata = {"render_modes": ["human"]} #, "rgb_array"], "render_fps": 4}

    def render(self, mode='human'):
        # Render the environment (optional)
        pass

    def close(self):
        # Clean up resources (optional)
        pass

# %%
''''class CNC_Env_Corrective_Pred(gymnasium.Env):

    def __init__(self, df):

        self.df = df
        self.reward_range = (np.NINF , 1 ) # Πρέπει να ορίσω το εύρος των rewards

        # Define the low and high bounds for each dimension of the action space
        low_bound = np.array([0, 0, 0], dtype=np.float64)
        high_bound = np.array([1, 1, 1], dtype=np.float64)

        # Action Space
        self.action_space = gymnasium.spaces.Box(low=low_bound, high=high_bound, dtype=np.float64)

        # Observation Space | Είναι κανονικοποιημένο από 0-1
        self.observation_space = gymnasium.spaces.Box(low=0, high=1, shape=(42,), dtype=np.float64)

        # Ξεκινάω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

    def _state_s0(self):
        # βάλε randomness εδώ
        self.current_step = 0
        # flute_1 = df[] diff bettwen d[1] - d[0] * (random val (0,2))
        # state_0 - ( state_1 - state_0)
        self.flute_1 = (2*self.df.loc[0, "flute_1"]) - self.df.loc[1, "flute_1"]
        self.flute_2 = (2*self.df.loc[0, "flute_2"]) - self.df.loc[1, "flute_2"]
        self.flute_3 =  (2*self.df.loc[0, "flute_3"]) - self.df.loc[1, "flute_3"]
        self.flute_max = (2*self.df.loc[0, "flute_max"]) - self.df.loc[1, "flute_max"]

        # Θέτουμε και τα predictions στην αρχική κατάσταση του συστήματος
        self.flute_1_pred = self.flute_1
        self.flute_2_pred = self.flute_2
        self.flute_3_pred = self.flute_3
        self.flute_max_pred = max(self.flute_1 , self.flute_2 , self.flute_3)

        self.pred_dif_1 = 0
        self.pred_dif_2 = 0
        self.pred_dif_3 = 0
        self.pred_dif_max = 0

    # Constructing Observations From Environment States
    def _get_obs(self):

        # Παίρνω τα time domain features του current (δηλαδή του αντίστοιχου cut)
        frame = self.df.loc[self.current_step, time_domain_features_columns].to_numpy(dtype=np.float64)

        # Φτιαχνω το observation
        obs = frame

        return obs

    def _get_info(self):
        return {
            "cut": self.current_step
        }

    def _take_action(self, action):

        # Βρες την διαφορά μεταξύ της προηγούμενης τιμής και της εκτιμόμενης τιμής

        # Action Space Example : array([0.79758393, 0.41074004, 0.0026002 ])

        # Αν θέλουμε μετά από κάθε state Sn να κάνουμε ένα Predict βάση του σωστού Sn-1
        self.flute_1_pred = self.flute_1 + (action[0] * MAX_DIFF)
        self.flute_2_pred = self.flute_2 + (action[1] * MAX_DIFF)
        self.flute_3_pred = self.flute_3 + (action[2] * MAX_DIFF)
        self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        ## Σε κάθε state Sn κάνουμε Predict βάση της προηγούμενης πρόβλεψης Sn-1
        #self.flute_1_pred = self.flute_1_pred + (action[0] * MAX_DIFF)    # !!!!!!!! flute_1_pred
        #self.flute_2_pred = self.flute_2_pred + (action[1] * MAX_DIFF)
        #self.flute_3_pred = self.flute_3_pred + (action[2] * MAX_DIFF)
        #self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        self.flute_1 = self.df.loc[self.current_step, "flute_1"]
        self.flute_2 = self.df.loc[self.current_step, "flute_2"]
        self.flute_3 = self.df.loc[self.current_step, "flute_3"]
        self.flute_max = self.df.loc[self.current_step, "flute_max"]

        # Η διαφορά μεταξύ της προβλεπόμενης τιμής και της κανονικής τιμής
        self.pred_dif_1 = self.flute_1_pred - self.flute_1
        self.pred_dif_2 = self.flute_1_pred - self.flute_1
        self.pred_dif_3 = self.flute_1_pred - self.flute_1
        self.pred_dif_max = self.flute_max_pred - self.flute_max

    def reset(self, seed = None, options = None):
        #We need the following line to seed self.np_random
        super().reset(seed=seed)

        # Επιστρέφω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

        # Set the current step to the start of the dataset
        self.current_step = 0

        observation = self._get_obs()
        info = self._get_info()

        return observation,info

    def score_function(self,delta):
        if delta < 0:
            return 1 - np.exp(-delta/10)
        else:
            return  1 - np.exp(delta/4.5)

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        # Παραμετροποιεί το reward έτσι ώστε να ενισχύει τις δράσεις που προσφέρουν οφέλοι σε μέλλοντα χρόνο
        #delay_modifier = (self.current_step / MAX_STEPS)

        reward_flute_1 = self.score_function(self.pred_dif_1)
        reward_flute_2 = self.score_function(self.pred_dif_2)
        reward_flute_3 = self.score_function(self.pred_dif_3)
        reward_flute_max = self.score_function(self.pred_dif_max)

        reward = (REW_WEIGHT[0]*reward_flute_1) + (REW_WEIGHT[1]*reward_flute_2) + (REW_WEIGHT[2]*reward_flute_3) + (REW_WEIGHT[3]*reward_flute_max)
        #reward = reward * delay_modifier

        # Ελέγχουμε εάν πάμε να βγούμε εκτός του dataset
        terminated = False
        if self.current_step > MAX_STEPS - 2:
            # τότε πρέπει να κάνουμε reset
            terminated = True  #διαλέγω terminated καθώς είναι φυσιολογική η λήξη

        observation = self._get_obs()
        info = self._get_info()

        #Εδω μπορούμε να βάλουμε κάποιο όριο απόκλισης τιμών στις προβλέψεις ώστε να κάνουμε την μάθηση ταχύτερη
        trunctated = False # Ελέγχουμε εάν υπάρχει κάποιο condition εξωτερικό του περιβάλλοντος πχ. Όριο χρόνου

        return observation, reward, terminated,trunctated, info

    metadata = {"render_modes": ["human"]} #, "rgb_array"], "render_fps": 4}

    def render(self, mode='human'):
        # Render the environment (optional)
        pass

    def close(self):
        # Clean up resources (optional)
        pass

# %%
class CNC_Env_Corrective_Pred_No_Delay(gymnasium.Env):

    def __init__(self, df):

        self.df = df
        self.reward_range = (np.NINF , 1 ) # Πρέπει να ορίσω το εύρος των rewards

        # Define the low and high bounds for each dimension of the action space
        low_bound = np.array([0, 0, 0], dtype=np.float64)
        high_bound = np.array([1, 1, 1], dtype=np.float64)

        # Action Space
        self.action_space = gymnasium.spaces.Box(low=low_bound, high=high_bound, dtype=np.float64)

        # Observation Space | Είναι κανονικοποιημένο από 0-1
        self.observation_space = gymnasium.spaces.Box(low=0, high=1, shape=(42,), dtype=np.float64)

        # Ξεκινάω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

    def _state_s0(self):
        # βάλε randomness εδώ
        self.current_step = 0
        # flute_1 = df[] diff bettwen d[1] - d[0] * (random val (0,2))
        # state_0 - ( state_1 - state_0)
        self.flute_1 = (2*self.df.loc[0, "flute_1"]) - self.df.loc[1, "flute_1"]
        self.flute_2 = (2*self.df.loc[0, "flute_2"]) - self.df.loc[1, "flute_2"]
        self.flute_3 =  (2*self.df.loc[0, "flute_3"]) - self.df.loc[1, "flute_3"]
        self.flute_max = (2*self.df.loc[0, "flute_max"]) - self.df.loc[1, "flute_max"]

        # Θέτουμε και τα predictions στην αρχική κατάσταση του συστήματος
        self.flute_1_pred = self.flute_1
        self.flute_2_pred = self.flute_2
        self.flute_3_pred = self.flute_3
        self.flute_max_pred = max(self.flute_1 , self.flute_2 , self.flute_3)

        self.pred_dif_1 = 0
        self.pred_dif_2 = 0
        self.pred_dif_3 = 0
        self.pred_dif_max = 0
        
        #Phm score
        self.score = 0 
        

    # Constructing Observations From Environment States
    def _get_obs(self):

        # Παίρνω τα time domain features του current (δηλαδή του αντίστοιχου cut)
        frame = self.df.loc[self.current_step, time_domain_features_columns].to_numpy(dtype=np.float64)

        # Φτιαχνω το observation
        obs = frame

        return obs

    def _get_info(self):
        return {
            "cut": self.current_step,
            "score": self.score,
        }
    

    def _take_action(self, action):

        # Βρες την διαφορά μεταξύ της προηγούμενης τιμής και της εκτιμόμενης τιμής

        # Action Space Example : array([0.79758393, 0.41074004, 0.0026002 ])

        # Αν θέλουμε μετά από κάθε state Sn να κάνουμε ένα Predict βάση του σωστού Sn-1
        self.flute_1_pred = self.flute_1 + (action[0] * MAX_DIFF)
        self.flute_2_pred = self.flute_2 + (action[1] * MAX_DIFF)
        self.flute_3_pred = self.flute_3 + (action[2] * MAX_DIFF)
        self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        self.flute_1 = self.df.loc[self.current_step, "flute_1"]
        self.flute_2 = self.df.loc[self.current_step, "flute_2"]
        self.flute_3 = self.df.loc[self.current_step, "flute_3"]
        self.flute_max = self.df.loc[self.current_step, "flute_max"]

        # Η διαφορά μεταξύ της προβλεπόμενης τιμής και της κανονικής τιμής
        self.pred_dif_1 = self.flute_1_pred - self.flute_1
        self.pred_dif_2 = self.flute_1_pred - self.flute_1
        self.pred_dif_3 = self.flute_1_pred - self.flute_1
        self.pred_dif_max = self.flute_max_pred - self.flute_max
        
        
    def reset(self, seed = None, options = None):
        #We need the following line to seed self.np_random
        super().reset(seed=seed)

        # Επιστρέφω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

        # Set the current step to the start of the dataset
        self.current_step = 0

        observation = self._get_obs()
        info = self._get_info()

        return observation,info
    
    def score_function_original(self, delta):
        if delta < 0:
            return np.exp(-delta/10) - 1
        else:
            return np.exp(delta/4.5) - 1

    def score_function(self,delta):
        if delta < 0:
            return 1 - np.exp(-delta/10)
        else:
            return  1 - np.exp(delta/4.5)

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        # Παραμετροποιεί το reward έτσι ώστε να ενισχύει τις δράσεις που προσφέρουν οφέλοι σε μέλλοντα χρόνο
        #delay_modifier = (self.current_step / MAX_STEPS)

        reward_flute_1 = self.score_function(self.pred_dif_1)
        reward_flute_2 = self.score_function(self.pred_dif_2)
        reward_flute_3 = self.score_function(self.pred_dif_3)
        reward_flute_max = self.score_function(self.pred_dif_max)

        reward = (REW_WEIGHT[0]*reward_flute_1) + (REW_WEIGHT[1]*reward_flute_2) + (REW_WEIGHT[2]*reward_flute_3) + (REW_WEIGHT[3]*reward_flute_max)
        #reward = reward * delay_modifier
        
        # H βαθμολογία που θα είχε στο διαγωνισμό
        self.score += self.score_function_original(self.pred_dif_max)
        
        info = self._get_info()
        
        # Ελέγχουμε εάν πάμε να βγούμε εκτός του dataset
        terminated = False
        if self.current_step > MAX_STEPS - 2:
            # τότε πρέπει να κάνουμε reset
            #print("Terminated at :" self.current_step)
            terminated = True  #διαλέγω terminated καθώς είναι φυσιολογική η λήξη

        observation = self._get_obs()

        #Εδω μπορούμε να βάλουμε κάποιο όριο απόκλισης τιμών στις προβλέψεις ώστε να κάνουμε την μάθηση ταχύτερη
        trunctated = False # Ελέγχουμε εάν υπάρχει κάποιο condition εξωτερικό του περιβάλλοντος πχ. Όριο χρόνου

        return observation, reward, terminated,trunctated, info

    metadata = {"render_modes": ["human"]} #, "rgb_array"], "render_fps": 4}

    def render(self, mode='human'):
        # Render the environment (optional)
        pass

    def close(self):
        # Clean up resources (optional)
        pass

# %%
class CNC_Env_Corrective_Pred_with_Delay(gymnasium.Env):

    def __init__(self, df):

        self.df = df
        self.reward_range = (np.NINF , 1 ) # Πρέπει να ορίσω το εύρος των rewards

        # Define the low and high bounds for each dimension of the action space
        low_bound = np.array([0, 0, 0], dtype=np.float64)
        high_bound = np.array([1, 1, 1], dtype=np.float64)

        # Action Space
        self.action_space = gymnasium.spaces.Box(low=low_bound, high=high_bound, dtype=np.float64)

        # Observation Space | Είναι κανονικοποιημένο από 0-1
        self.observation_space = gymnasium.spaces.Box(low=0, high=1, shape=(42,), dtype=np.float64)

        # Ξεκινάω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

    def _state_s0(self):
        # βάλε randomness εδώ
        self.current_step = 0
        # flute_1 = df[] diff bettwen d[1] - d[0] * (random val (0,2))
        # state_0 - ( state_1 - state_0)
        self.flute_1 = (2*self.df.loc[0, "flute_1"]) - self.df.loc[1, "flute_1"]
        self.flute_2 = (2*self.df.loc[0, "flute_2"]) - self.df.loc[1, "flute_2"]
        self.flute_3 =  (2*self.df.loc[0, "flute_3"]) - self.df.loc[1, "flute_3"]
        self.flute_max = (2*self.df.loc[0, "flute_max"]) - self.df.loc[1, "flute_max"]

        # Θέτουμε και τα predictions στην αρχική κατάσταση του συστήματος
        self.flute_1_pred = self.flute_1
        self.flute_2_pred = self.flute_2
        self.flute_3_pred = self.flute_3
        self.flute_max_pred = max(self.flute_1 , self.flute_2 , self.flute_3)

        self.pred_dif_1 = 0
        self.pred_dif_2 = 0
        self.pred_dif_3 = 0
        self.pred_dif_max = 0
        
        #Phm score
        self.score = 0 

    # Constructing Observations From Environment States
    def _get_obs(self):

        # Παίρνω τα time domain features του current (δηλαδή του αντίστοιχου cut)
        frame = self.df.loc[self.current_step, time_domain_features_columns].to_numpy(dtype=np.float64)

        # Φτιαχνω το observation
        obs = frame

        return obs

    def _get_info(self):
        return {
            "cut": self.current_step,
            "score": self.score
        }
    

    def _take_action(self, action):

        # Βρες την διαφορά μεταξύ της προηγούμενης τιμής και της εκτιμόμενης τιμής

        # Action Space Example : array([0.79758393, 0.41074004, 0.0026002 ])

        # Αν θέλουμε μετά από κάθε state Sn να κάνουμε ένα Predict βάση του σωστού Sn-1
        self.flute_1_pred = self.flute_1 + (action[0] * MAX_DIFF)
        self.flute_2_pred = self.flute_2 + (action[1] * MAX_DIFF)
        self.flute_3_pred = self.flute_3 + (action[2] * MAX_DIFF)
        self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        self.flute_1 = self.df.loc[self.current_step, "flute_1"]
        self.flute_2 = self.df.loc[self.current_step, "flute_2"]
        self.flute_3 = self.df.loc[self.current_step, "flute_3"]
        self.flute_max = self.df.loc[self.current_step, "flute_max"]

        # Η διαφορά μεταξύ της προβλεπόμενης τιμής και της κανονικής τιμής
        self.pred_dif_1 = self.flute_1_pred - self.flute_1
        self.pred_dif_2 = self.flute_1_pred - self.flute_1
        self.pred_dif_3 = self.flute_1_pred - self.flute_1
        self.pred_dif_max = self.flute_max_pred - self.flute_max
        
        
    def reset(self, seed = None, options = None):
        #We need the following line to seed self.np_random
        super().reset(seed=seed)

        # Επιστρέφω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

        # Set the current step to the start of the dataset
        self.current_step = 0

        observation = self._get_obs()
        info = self._get_info()

        return observation,info
    
    def score_function_original(self, delta):
        if delta < 0:
            return np.exp(-delta/10) - 1
        else:
            return np.exp(delta/4.5) - 1

    def score_function(self,delta):
        if delta < 0:
            return 1 - np.exp(-delta/10)
        else:
            return  1 - np.exp(delta/4.5)

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        reward_flute_1 = self.score_function(self.pred_dif_1)
        reward_flute_2 = self.score_function(self.pred_dif_2)
        reward_flute_3 = self.score_function(self.pred_dif_3)
        reward_flute_max = self.score_function(self.pred_dif_max)

        reward_without_delay = (REW_WEIGHT[0]*reward_flute_1) + (REW_WEIGHT[1]*reward_flute_2) + (REW_WEIGHT[2]*reward_flute_3) + (REW_WEIGHT[3]*reward_flute_max)
        # Παραμετροποιεί το reward έτσι ώστε να ενισχύει τις δράσεις που προσφέρουν οφέλοι σε μέλλοντα χρόνο
        delay_modifier = (self.current_step / (MAX_STEPS-2))
        reward = reward_without_delay * delay_modifier
        
        # H βαθμολογία που θα είχε στο διαγωνισμό
        self.score += self.score_function_original(self.pred_dif_max)
        
        info = self._get_info()
        
        # Ελέγχουμε εάν πάμε να βγούμε εκτός του dataset
        terminated = False
        if self.current_step > MAX_STEPS - 2:
            # τότε πρέπει να κάνουμε reset
            terminated = True  #διαλέγω terminated καθώς είναι φυσιολογική η λήξη

        observation = self._get_obs()

        #Εδω μπορούμε να βάλουμε κάποιο όριο απόκλισης τιμών στις προβλέψεις ώστε να κάνουμε την μάθηση ταχύτερη
        trunctated = False # Ελέγχουμε εάν υπάρχει κάποιο condition εξωτερικό του περιβάλλοντος πχ. Όριο χρόνου

        return observation, reward, terminated,trunctated, info

    metadata = {"render_modes": ["human"]} #, "rgb_array"], "render_fps": 4}

    def render(self, mode='human'):
        # Render the environment (optional)
        pass

    def close(self):
        # Clean up resources (optional)
        pass

# %%
class CNC_Env_Non_Corrective_No_Delay(gymnasium.Env):

    def __init__(self, df):

        self.df = df
        self.reward_range = (np.NINF , 1 ) # Πρέπει να ορίσω το εύρος των rewards

        # Define the low and high bounds for each dimension of the action space
        low_bound = np.array([0, 0, 0], dtype=np.float64)
        high_bound = np.array([1, 1, 1], dtype=np.float64)

        # Action Space
        self.action_space = gymnasium.spaces.Box(low=low_bound, high=high_bound, dtype=np.float64)

        # Observation Space | Είναι κανονικοποιημένο από 0-1 | 7 sensors * 6 time domain features = 42
        self.observation_space = gymnasium.spaces.Box(low=0, high=1, shape=(42,), dtype=np.float64)

        # Ξεκινάω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

    def _state_s0(self):
        # βάλε randomness εδώ
        self.current_step = 0
        # flute_1 = df[] diff bettwen d[1] - d[0] * (random val (0,2))
        # state_0 - ( state_1 - state_0)
        self.flute_1 = (2*self.df.loc[0, "flute_1"]) - self.df.loc[1, "flute_1"]
        self.flute_2 = (2*self.df.loc[0, "flute_2"]) - self.df.loc[1, "flute_2"]
        self.flute_3 =  (2*self.df.loc[0, "flute_3"]) - self.df.loc[1, "flute_3"]
        self.flute_max = (2*self.df.loc[0, "flute_max"]) - self.df.loc[1, "flute_max"]

        # Θέτουμε και τα predictions στην αρχική κατάσταση του συστήματος
        self.flute_1_pred = self.flute_1
        self.flute_2_pred = self.flute_2
        self.flute_3_pred = self.flute_3
        self.flute_max_pred = max(self.flute_1 , self.flute_2 , self.flute_3)

        self.pred_dif_1 = 0
        self.pred_dif_2 = 0
        self.pred_dif_3 = 0
        self.pred_dif_max = 0
        
        #Phm Score
        self.score = 0 

    # Constructing Observations From Environment States
    def _get_obs(self):

        # Παίρνω τα time domain features του current (δηλαδή του αντίστοιχου cut)
        frame = self.df.loc[self.current_step, time_domain_features_columns].to_numpy(dtype=np.float64)

        # Φτιαχνω το observation
        obs = frame

        return obs

    def _get_info(self):
        return {
            "cut": self.current_step,
            "score": self.score,
        }

    def _take_action(self, action):

        # Action Space Example : array([0.79758393, 0.41074004, 0.0026002 ])

        ## Σε κάθε state Sn κάνουμε Predict βάση της προηγούμενης πρόβλεψης Sn-1
        # Φθορα στο μυτακι_1(ν) = φθορα στο μυτακι_1_πρβλεπομενη(ν-1) + prediction του agent
        # Prediction του agent = 100% max diff φθορών σε καταστασεις χρησεις του μηχανηματος (ν -> ν+1)
        
        self.flute_1_pred += (action[0] * MAX_DIFF)
        self.flute_2_pred += (action[1] * MAX_DIFF)
        self.flute_3_pred += (action[2] * MAX_DIFF)
        self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        self.flute_1 = self.df.loc[self.current_step, "flute_1"]
        self.flute_2 = self.df.loc[self.current_step, "flute_2"]
        self.flute_3 = self.df.loc[self.current_step, "flute_3"]
        self.flute_max = self.df.loc[self.current_step, "flute_max"]

        # Η διαφορά μεταξύ της προβλεπόμενης τιμής και της κανονικής τιμής
        self.pred_dif_1 = self.flute_1_pred - self.flute_1
        self.pred_dif_2 = self.flute_1_pred - self.flute_1
        self.pred_dif_3 = self.flute_1_pred - self.flute_1
        self.pred_dif_max = self.flute_max_pred - self.flute_max

    def reset(self, seed = None, options = None):
        #We need the following line to seed self.np_random
        super().reset(seed=seed)

        # Επιστρέφω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

        # Set the current step to the start of the dataset
        self.current_step = 0

        observation = self._get_obs()

        info = self._get_info()

        return observation,info

    def score_function(self,delta):
        if delta < 0:
            return 1 - np.exp(-delta/10)
        else:
            return  1 - np.exp(delta/4.5)
        

    def score_function_original(self, delta):
        if delta < 0:
            return np.exp(-delta/10) - 1
        else:
            return np.exp(delta/4.5) - 1

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        reward_flute_1 = self.score_function(self.pred_dif_1)
        reward_flute_2 = self.score_function(self.pred_dif_2)
        reward_flute_3 = self.score_function(self.pred_dif_3)
        reward_flute_max = self.score_function(self.pred_dif_max)

        reward = (REW_WEIGHT[0]*reward_flute_1) + (REW_WEIGHT[1]*reward_flute_2) + (REW_WEIGHT[2]*reward_flute_3) + (REW_WEIGHT[3]*reward_flute_max)

        # H βαθμολογία που θα είχε στο διαγωνισμό
        #self.score -= reward_flute_max
        
        # H βαθμολογία που θα είχε στο διαγωνισμό
        self.score += self.score_function_original(self.pred_dif_max)
        
        
        info = self._get_info()
        #print("In the env self.score is : ", self.score)
        #print(info)
        
        # Ελέγχουμε εάν πάμε να βγούμε εκτός του dataset
        terminated = False
        if self.current_step > MAX_STEPS - 2:
            # τότε πρέπει να κάνουμε reset)
            print("Reached 314", print(info))
            info = self._get_info()

            terminated = True  #διαλέγω terminated καθώς είναι φυσιολογική η λήξη

        observation = self._get_obs()

        #Εδω μπορούμε να βάλουμε κάποιο όριο απόκλισης τιμών στις προβλέψεις ώστε να κάνουμε την μάθηση ταχύτερη
        trunctated = False # Ελέγχουμε εάν υπάρχει κάποιο condition εξωτερικό του περιβάλλοντος πχ. Όριο χρόνου
        if reward < -200000000 : #200 million
            trunctated = True

        return observation, reward, terminated,trunctated, info

    metadata = {"render_modes": ["human"]} #, "rgb_array"], "render_fps": 4}

    def render(self, mode='human'):
        # Render the environment (optional)
        pass

    def close(self):
        # Clean up resources (optional)
        pass

# %%
class CNC_Env_Non_Corrective_with_Delay(gymnasium.Env):

    def __init__(self, df):

        self.df = df
        self.reward_range = (np.NINF , 1 ) # Πρέπει να ορίσω το εύρος των rewards

        # Define the low and high bounds for each dimension of the action space
        low_bound = np.array([0, 0, 0], dtype=np.float64)
        high_bound = np.array([1, 1, 1], dtype=np.float64)

        # Action Space
        self.action_space = gymnasium.spaces.Box(low=low_bound, high=high_bound, dtype=np.float64)

        # Observation Space | Είναι κανονικοποιημένο από 0-1 | 7 sensors * 6 time domain features = 42
        self.observation_space = gymnasium.spaces.Box(low=0, high=1, shape=(42,), dtype=np.float64)

        # Ξεκινάω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

    def _state_s0(self):
        # βάλε randomness εδώ
        self.current_step = 0
        # flute_1 = df[] diff bettwen d[1] - d[0] * (random val (0,2))
        # state_0 - ( state_1 - state_0)
        self.flute_1 = (2*self.df.loc[0, "flute_1"]) - self.df.loc[1, "flute_1"]
        self.flute_2 = (2*self.df.loc[0, "flute_2"]) - self.df.loc[1, "flute_2"]
        self.flute_3 =  (2*self.df.loc[0, "flute_3"]) - self.df.loc[1, "flute_3"]
        self.flute_max = (2*self.df.loc[0, "flute_max"]) - self.df.loc[1, "flute_max"]

        # Θέτουμε και τα predictions στην αρχική κατάσταση του συστήματος
        self.flute_1_pred = self.flute_1
        self.flute_2_pred = self.flute_2
        self.flute_3_pred = self.flute_3
        self.flute_max_pred = max(self.flute_1 , self.flute_2 , self.flute_3)

        self.pred_dif_1 = 0
        self.pred_dif_2 = 0
        self.pred_dif_3 = 0
        self.pred_dif_max = 0
        
        #Phm Score
        self.score = 0 

    # Constructing Observations From Environment States
    def _get_obs(self):

        # Παίρνω τα time domain features του current (δηλαδή του αντίστοιχου cut)
        frame = self.df.loc[self.current_step, time_domain_features_columns].to_numpy(dtype=np.float64)

        # Φτιαχνω το observation
        obs = frame

        return obs

    def _get_info(self):
        return {
            "cut": self.current_step,
            "score": self.score
        }

    def _take_action(self, action):

        # Action Space Example : array([0.79758393, 0.41074004, 0.0026002 ])

        ## Σε κάθε state Sn κάνουμε Predict βάση της προηγούμενης πρόβλεψης Sn-1
        # Φθορα στο μυτακι_1(ν) = φθορα στο μυτακι_1_πρβλεπομενη(ν-1) + prediction του agent
        # Prediction του agent = 100% max diff φθορών σε καταστασεις χρησεις του μηχανηματος (ν -> ν+1)
        
        self.flute_1_pred += (action[0] * MAX_DIFF)
        self.flute_2_pred += (action[1] * MAX_DIFF)
        self.flute_3_pred += (action[2] * MAX_DIFF)
        self.flute_max_pred = max(self.flute_1_pred , self.flute_2_pred , self.flute_3_pred)

        self.flute_1 = self.df.loc[self.current_step, "flute_1"]
        self.flute_2 = self.df.loc[self.current_step, "flute_2"]
        self.flute_3 = self.df.loc[self.current_step, "flute_3"]
        self.flute_max = self.df.loc[self.current_step, "flute_max"]

        # Η διαφορά μεταξύ της προβλεπόμενης τιμής και της κανονικής τιμής
        self.pred_dif_1 = self.flute_1_pred - self.flute_1
        self.pred_dif_2 = self.flute_1_pred - self.flute_1
        self.pred_dif_3 = self.flute_1_pred - self.flute_1
        self.pred_dif_max = self.flute_max_pred - self.flute_max

    def reset(self, seed = None, options = None):
        #We need the following line to seed self.np_random
        super().reset(seed=seed)

        # Επιστρέφω το περιβάλλον στην αρχική του κατάσταση (state s0)
        self._state_s0()

        # Set the current step to the start of the dataset
        self.current_step = 0

        observation = self._get_obs()
        info = self._get_info()

        return observation,info

    def score_function(self,delta):
        if delta < 0:
            return 1 - np.exp(-delta/10)
        else:
            return  1 - np.exp(delta/4.5)
        
    def score_function_original(self, delta):
        if delta < 0:
            return np.exp(-delta/10) - 1
        else:
            return np.exp(delta/4.5) - 1

    def step(self, action):
        # Execute one time step within the environment
        self._take_action(action)

        self.current_step += 1

        reward_flute_1 = self.score_function(self.pred_dif_1)
        reward_flute_2 = self.score_function(self.pred_dif_2)
        reward_flute_3 = self.score_function(self.pred_dif_3)
        reward_flute_max = self.score_function(self.pred_dif_max) #PHM 

        reward_without_delay = (REW_WEIGHT[0]*reward_flute_1) + (REW_WEIGHT[1]*reward_flute_2) + (REW_WEIGHT[2]*reward_flute_3) + (REW_WEIGHT[3]*reward_flute_max)
        # Παραμετροποιεί το reward έτσι ώστε να ενισχύει τις δράσεις που προσφέρουν οφέλοι σε μέλλοντα χρόνο
        delay_modifier = (self.current_step / (MAX_STEPS-2))
        reward = reward_without_delay * delay_modifier 
        
        # H βαθμολογία που θα είχε στο διαγωνισμό
        #self.score -= reward_flute_max
        
        self.score += self.score_function_original(self.pred_dif_max)
    
        info = self._get_info()
    
        # Ελέγχουμε εάν πάμε να βγούμε εκτός του dataset
        terminated = False
        if self.current_step > MAX_STEPS - 2:
            # τότε πρέπει να κάνουμε reset)
            terminated = True  #διαλέγω terminated καθώς είναι φυσιολογική η λήξη

        observation = self._get_obs()

        #Εδω μπορούμε να βάλουμε κάποιο όριο απόκλισης τιμών στις προβλέψεις ώστε να κάνουμε την μάθηση ταχύτερη
        trunctated = False # Ελέγχουμε εάν υπάρχει κάποιο condition εξωτερικό του περιβάλλοντος πχ. Όριο χρόνου
        if reward < -200000000 : #200milion
            trunctated = True

        return observation, reward, terminated,trunctated, info

    metadata = {"render_modes": ["human"]} #, "rgb_array"], "render_fps": 4}

    def render(self, mode='human'):
        # Render the environment (optional)
        pass

    def close(self):
        # Clean up resources (optional)
        pass

# %%
# Create an instance of the environment with your dataframe
c1_non_corrective_pred_no_delay_env = CNC_Env_Non_Corrective_No_Delay(df)
c1_non_corrective_pred_with_delay_env = CNC_Env_Non_Corrective_with_Delay(df)

c1_corrective_pred_no_delay_env = CNC_Env_Corrective_Pred_No_Delay(df)
c1_corrective_pred_with_delay_env = CNC_Env_Corrective_Pred_with_Delay(df)

# %%
check_env(c1_non_corrective_pred_no_delay_env, warn=True)
check_env(c1_non_corrective_pred_with_delay_env, warn=True)
check_env(c1_corrective_pred_no_delay_env, warn=True)
check_env(c1_corrective_pred_with_delay_env,warn=True)

# %%
# Define the log path
#log_path = os.path.join('training', 'logs')

# Create log directory if it doesn't exist
#os.makedirs(log_path, exist_ok=True)

# Wrap the environment with the Monitor
#non_corrective_pred_env = Monitor(non_corrective_pred_env, log_path)

# Wrap the environment with the Monitor
#corrective_pred_env = Monitor(corrective_pred_env, log_path)

# %%
# Training Help
TIMESTEPS = 10000

# Create a log path for our training logs 
logdir = "logs"
if not os.path.exists(logdir):
    os.makedirs(logdir)

# %% [markdown]
# ### Tensorboard Command
# C:\path >tensorboard --logdir=logs

# %% [markdown]
# ## Helper Functions

# %%
# Function to find the highest 'i' value from existing model files
def find_highest_i(models_dir):
    highest_i = 0
    for filename in os.listdir(models_dir):
        if filename.endswith(".zip"):  # Ensure we're only looking at model files
            try:
                # Extract 'i' from the filename based on the TIMESTEPS*i pattern
                i = int(filename.replace('.zip', '').split('/')[-1]) // TIMESTEPS
                if i > highest_i:
                    highest_i = i
            except ValueError:
                # In case the filename doesn't follow the expected pattern
                continue
    return highest_i

# %%
def make_filename(models_dir): 
    if not os.path.exists(models_dir): 
        os.makedirs(models_dir)

    highest_i = find_highest_i(models_dir)
    return f"{models_dir}/{TIMESTEPS*highest_i}.zip"

# %% [markdown]
# ### **Callback**

# %%
from stable_baselines3.common.callbacks import BaseCallback
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# Define a custom callback to log the score during training
class ScoreLoggerCallback(BaseCallback):
    def __init__(self, verbose=0):
        super(ScoreLoggerCallback, self).__init__(verbose) 
        self.max_score = 0  # Define max_score attribute here

    def _on_step(self) -> bool:
        # Retrieve the wrapped environment from the model
        env = self.model.env.envs[0]  # Assuming you only have one environment in the DummyVecEnv
        
        # Log the score after each training step
        phm_score = env.score
          
        current_step = env.current_step 
        if current_step < (MAX_STEPS - 5):
            # Log the maximum score achieved so far when current step is less than MAX_STEPS - 5
            self.logger.record("rollout/phm_score", self.max_score)
            #print("Current Step is :", current_step)
            #print("The score LESS THAN 315 is :", phm_score)
        
        if current_step >= (MAX_STEPS - 2):
            # Log the score and update max_score when current step is greater than or equal to MAX_STEPS - 2
            self.max_score = phm_score  # Update max_score
            self.logger.record("rollout/phm_score", phm_score)
            #print("Current Step is :", current_step)
            #print("The score at 315 is :", phm_score)
            
        return True

# %% [markdown]
# ### **Load Model**

# %%
def load_model(model_filename, algo, env):
    if Path(model_filename).exists():
        algo_class = getattr(stable_baselines3, algo)
        loaded_model = algo_class.load(model_filename, env)
        print(f"Successfully loaded model from {model_filename}")
        return loaded_model 
    else:
        print(f"Model file '{model_filename}' does not exist.")

# %% [markdown]
# ### **Run Model**

# %%
def run_model(env, algo, log_name,  models_dir, max_loops , max_time, first_run, model=None):
    
    callback = ScoreLoggerCallback()
    model_filename = make_filename(models_dir)
    highest_i = find_highest_i(models_dir)
    i = highest_i + 1
    di = i 
    start_time = time.time()
    
    while True:
    
        model_filename = make_filename(models_dir)
    
        if first_run : 
            model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=log_name, callback=callback)
            model_filename = f"{models_dir}/{TIMESTEPS*i}.zip"
            model.save(model_filename)
            i+1
            first_run = False
            
        model = load_model(model_filename, algo, env)
        model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=log_name, callback=callback)
        
        model_filename = f"{models_dir}/{TIMESTEPS*i}.zip"
        model.save(model_filename)

        reward, _= evaluate_policy(model, env, n_eval_episodes=2, render=False)
        print(reward)
        i += 1
        
        #trackers
        diff_timesteps = i - di
        print("diff_timesteps is ", diff_timesteps)
        elapsed_time = time.time() - start_time
        print("Elasped time is (sec)",elapsed_time )
        if diff_timesteps > max_loops or elapsed_time > max_time :
            break

# %% [markdown]
# **Warnings Supressor**

# %%
# Reset warnings to default state
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
#warnings.resetwarnings()

# %% [markdown]
# # Algorithms

# %% [markdown]
# #### Create the models
# We run it only once, after that we load each model

# %%
## -- PPO -- ##
#ppo_model_non_corr_no_delay = PPO("MlpPolicy", c1_non_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#ppo_model_non_corr_with_delay = PPO("MlpPolicy", c1_non_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)
#---------------------
#ppo_model_corr_no_delay = PPO("MlpPolicy", c1_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#ppo_model_corr_with_delay = PPO("MlpPolicy", c1_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)
#---------------------

## -- A2C -- ##
#a2c_model_non_corr_no_delay = A2C("MlpPolicy", c1_non_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#a2c_model_non_corr_with_delay = A2C("MlpPolicy", c1_non_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)
#---------------------
#a2c_model_corr_no_delay = A2C("MlpPolicy", c1_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#a2c_model_corr_with_delay = A2C("MlpPolicy", c1_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)

## -- DDPG -- ##
#ddpg_model_non_corr_no_delay = DDPG("MlpPolicy", c1_non_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#ddpg_model_non_corr_with_delay = DDPG("MlpPolicy", c1_non_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)
#---------------------
#ddpg_model_corr_no_delay = DDPG("MlpPolicy", c1_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#ddpg_model_corr_with_delay = DDPG("MlpPolicy", c1_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)

## -- SAC -- ##
#sac_model_non_corr_no_delay = SAC("MlpPolicy", c1_non_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#sac_model_non_corr_with_delay = SAC("MlpPolicy", c1_non_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)
#---------------------
#sac_model_corr_no_delay = SAC("MlpPolicy", c1_corrective_pred_no_delay_env, verbose=1, tensorboard_log = logdir)
#sac_model_corr_with_delay = SAC("MlpPolicy", c1_corrective_pred_with_delay_env, verbose=1, tensorboard_log = logdir)

# %% [markdown]
# # PPO

# %% [markdown]
# ### PPO Non Corrective No Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "PPO", "PPO_model_non_corr_no_delay", "models/PPO_non_corr_no_delay", 1, 3600, True, ppo_model_non_corr_no_delay) #1hour   
# -----------
# MAIN RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "PPO", "PPO_model_non_corr_no_delay", "models/PPO_non_corr_no_delay", 10, 3600, False,)

# %% [markdown]
# ### PPO Non Corrective With Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_with_delay_env, "PPO", "PPO_model_non_corr_with_delay", "models/PPO_non_corr_with_delay", 1, 3600, True, ppo_model_non_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_non_corrective_pred_with_delay_env, "PPO", "PPO_model_non_corr_with_delay", "models/PPO_non_corr_with_delay", 1000, 10200, False,)

# %% [markdown]
# ### PPO Corrective No Delay

# %%
# FIRST RUN
#run_model(c1_corrective_pred_no_delay_env, "PPO", "PPO_model_corr_no_delay", "models/PPO_corr_no_delay", 1, 3600, True, ppo_model_corr_no_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_corrective_pred_no_delay_env, "PPO", "PPO_model_corr_no_delay", "models/PPO_corr_no_delay", 1, 3600, False,)

# %% [markdown]
# ### PPO Corrective With Delay

# %%
# FIRST RUN 
#run_model(c1_corrective_pred_with_delay_env, "PPO", "PPO_model_corr_with_delay", "models/PPO_corr_with_delay", 1, 3600, True, ppo_model_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_corrective_pred_with_delay_env, "PPO", "PPO_model_corr_with_delay", "models/PPO_corr_with_delay", 100, 3600, False,)

# %% [markdown]
# #### PPO Corrective No Delay (Test 1)

# %%
#models_dir = "models\PPO_non_corr_no_delay_test" 
#ppo_model_non_corr_no_delay_test.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO_non_corr_no_delay_test", callback=callback)

# %% [markdown]
# #### PPO Corrective No Delay (Test 2)

# %%
#model_filename = make_filename("models\PPO_non_corr_no_delay_test", TIMESTEPS)
#ppo_corrective_no_delay_test_2 = log_name , model_dir

#ppo_model_non_corr_no_delay_test <- MODEL ,  tb_log_name="PPO_non_corr_no_delay_test2" , models_dir = "models\PPO_non_corr_no_delay_test"

# %%
#run_model(ppo_corrective_no_delay_test_2, c1_non_corrective_pred_no_delay_env, "ppo_model_non_corr_no_delay", "models/a2c_non_corr_no_delay", 0, 3600) #1hour

# %%
# Load PPO_non_corr Model 
#model_filename = make_filename("models\PPO_non_corr_no_delay", TIMESTEPS)
#ppo_model_non_corr_no_delay = PPO.load(model_filename, exp)
#print(f"Successfully loaded model from {model_filename}")

# %%
# Load PPO_non_corr Model TEST 
#model_filename = make_filename("models\PPO_non_corr_no_delay_test", TIMESTEPS)
#ppo_model_non_corr_no_delay_test = PPO.load(model_filename, c1_non_corrective_pred_no_delay_env )
#print(f"Successfully loaded model from {model_filename}")

# %%
# Train PPO_non_corr_no_delay
#models_dir = "models\PPO_non_corr_no_delay_test"
#highest_i = find_highest_i("models\PPO_non_corr_no_delay_test", TIMESTEPS)
# Adjust the range based on the highest 'i' found
#for i in range(highest_i + 1, highest_i + 31):  # Starts from the next available 'i'
#    ppo_model_non_corr_no_delay_test.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO_non_corr_no_delay_test", callback=callback)
#    model_filename = f"{models_dir}/{TIMESTEPS*i}.zip"
#    ppo_model_non_corr_no_delay_test.save(model_filename)

# %%
#model_filename = make_filename("models\PPO_non_corr_no_delay_test", TIMESTEPS)

# %%
#models_dir = "models\PPO_non_corr_no_delay_test"
#i = find_highest_i(models_dir, TIMESTEPS)
#print(i)
#print(TIMESTEPS)
#model_filename = f"{models_dir}/{TIMESTEPS*i}.zip"

#print(model_filename)

# %%
#models_dir = "models\PPO_non_corr_no_delay_test"
#highest_i = find_highest_i(models_dir, TIMESTEPS)
#callback = ScoreLoggerCallback()

#---------

#----------

# Wrap the environment with Monitor and DummyVecEnv
#env = c1_non_corrective_pred_no_delay_env
#env = Monitor(env)
#env = DummyVecEnv([lambda: env])
#ppo_model_non_corr_no_delay = PPO("MlpPolicy", env, verbose=1, tensorboard_log = logdir)
# Adjust the range based on the highest 'i' found
#i = highest_i + 1
#while True:
#    ppo_model_non_corr_no_delay_test.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO_non_corr_no_delay_test2", callback=callback)
#    model_filename = f"{models_dir}/{TIMESTEPS*i}.zip"
#    
#    ppo_model_non_corr_no_delay_test.save(model_filename)
#    
    # Evaluate the model to check if the reward is greater than -4000
    # Assuming you have a function to evaluate the model and return its reward
#    reward, _ = evaluate_policy(ppo_model_non_corr_no_delay, c1_non_corrective_pred_no_delay_env, n_eval_episodes=2, render=False)
#    print(reward)
#    if reward > -4000:
#        break  # Exit the loop if reward exceeds -4000
#    i += 1

# %% [markdown]
# # A2C

# %% [markdown]
# ### A2C Non Corrective No Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "A2C", "A2C_model_non_corr_no_delay", "models/A2C_non_corr_no_delay", 1, 3600, True, a2c_model_non_corr_no_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "A2C", "A2C_model_non_corr_no_delay", "models/A2C_non_corr_no_delay", 100, 3600, False,)

# %% [markdown]
# ### A2C Non Corrective With Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "A2C", "A2C_model_non_corr_with_delay", "models/A2C_non_corr_with_delay", 1, 3600, True, a2c_model_non_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_non_corrective_pred_with_delay_env, "A2C", "A2C_model_non_corr_with_delay", "models/A2C_non_corr_with_delay", 1200, 8600, False,)

# %% [markdown]
# ### A2C Corrective No Delay

# %%
# FIRST RUN 
#run_model(c1_corrective_pred_no_delay_env, "A2C", "A2C_model_corr_no_delay", "models/A2C_corr_no_delay", 1, 3600, True, a2c_model_corr_no_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "A2C", "A2C_model_corr_no_delay", "models/A2C_corr_no_delay", 100, 3600, False,)

# %% [markdown]
# ### A2C Corrective With Delay

# %%
# FIRST RUN 
#run_model(c1_corrective_pred_with_delay_env, "A2C", "A2C_model_corr_with_delay", "models/A2C_corr_with_delay", 1, 3600, True, a2c_model_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_corrective_pred_with_delay_env, "A2C", "A2C_model_corr_with_delay", "models/A2C_corr_with_delay", 1000, 10600, False,)

# %% [markdown]
# # **DDPG**

# %% [markdown]
# ### DDPG Non Corrective No Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "DDPG", "DDPG_model_non_corr_no_delay", "models/DDPG_non_corr_no_delay", 1, 3600, True, ddpg_model_non_corr_no_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "DDPG", "DDPG_model_non_corr_no_delay", "models/DDPG_non_corr_no_delay", 100, 4600, False,)

# %% [markdown]
# ### DDPG Non Corrective With Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_with_delay_env, "DDPG", "DDPG_model_non_corr_with_delay", "models/DDPG_non_corr_with_delay", 1, 3600, True, ddpg_model_non_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_non_corrective_pred_with_delay_env, "DDPG", "DDPG_model_non_corr_with_delay", "models/DDPG_non_corr_with_delay", 100, 4600, False,)

# %% [markdown]
# ### DDPG Corrective No Delay

# %%
# FIRST RUN 
#run_model(c1_corrective_pred_no_delay_env, "DDPG", "DDPG_model_corr_no_delay", "models/DDPG_corr_no_delay", 1, 3600, True, ddpg_model_corr_no_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_corrective_pred_no_delay_env, "DDPG", "DDPG_model_corr_no_delay", "models/DDPG_corr_no_delay", 1000, 10600, False,)

# %% [markdown]
# ### DDPG Corrective With Delay

# %%
# FIRST RUN 
#run_model(c1_corrective_pred_with_delay_env, "DDPG", "DDPG_model_corr_with_delay", "models/DDPG_corr_with_delay", 1, 3600, True, ddpg_model_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_corrective_pred_with_delay_env, "DDPG", "DDPG_model_corr_with_delay", "models/DDPG_corr_with_delay", 1000, 4000, False,)

# %% [markdown]
# # **SAC**

# %% [markdown]
# ### SAC Non Corrective Νo Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_no_delay_env, "SAC", "SAC_model_non_corr_no_delay", "models/SAC_non_corr_no_delay", 1, 3600, True, sac_model_non_corr_no_delay) #1hour   
#-------------
# MAIN RUN 
run_model(c1_non_corrective_pred_no_delay_env, "SAC", "SAC_model_non_corr_no_delay", "models/SAC_non_corr_no_delay", 1000, 6600, False,)
# Out:
# Wrapping the env in a DummyVecEnv.
# Successfully loaded model from models/SAC_non_corr_no_delay/3600000.zip
# Logging to logs\SAC_model_non_corr_no_delay_0
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.59e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90920     |
# |    fps             | 35        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 3610099   |
# | train/             |           |
# |    actor_loss      | 1.66e+10  |
# |    critic_loss     | 1.21e+15  |
# |    ent_coef        | 5.86e+06  |
# |    ent_coef_loss   | -1.98     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3609998   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.54e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90924     |
# |    fps             | 36        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 3610230   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.11e+15  |
# |    ent_coef        | 5.85e+06  |
# |    ent_coef_loss   | 2         |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3610129   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.1      |
# |    ep_rew_mean     | -5.44e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90928     |
# |    fps             | 36        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 3610362   |
# | train/             |           |
# |    actor_loss      | 1.65e+10  |
# |    critic_loss     | 1.02e+15  |
# |    ent_coef        | 5.78e+06  |
# |    ent_coef_loss   | 2.22      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3610261   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.1      |
# |    ep_rew_mean     | -5.45e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90932     |
# |    fps             | 36        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 3610495   |
# | train/             |           |
# |    actor_loss      | 1.65e+10  |
# |    critic_loss     | 1.41e+15  |
# |    ent_coef        | 5.75e+06  |
# |    ent_coef_loss   | -1.61     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3610394   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.1     |
# |    ep_rew_mean     | -5.4e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 90936    |
# |    fps             | 36       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 3610628  |
# | train/             |          |
# |    actor_loss      | 1.68e+10 |
# |    critic_loss     | 1.73e+15 |
# |    ent_coef        | 5.73e+06 |
# |    ent_coef_loss   | -5.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3610527  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.1      |
# |    ep_rew_mean     | -5.35e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90940     |
# |    fps             | 36        |
# |    time_elapsed    | 20        |
# |    total_timesteps | 3610761   |
# | train/             |           |
# |    actor_loss      | 1.66e+10  |
# |    critic_loss     | 1.16e+15  |
# |    ent_coef        | 5.68e+06  |
# |    ent_coef_loss   | -0.963    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3610660   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.1      |
# |    ep_rew_mean     | -5.36e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90944     |
# |    fps             | 36        |
# |    time_elapsed    | 24        |
# |    total_timesteps | 3610894   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.65e+15  |
# |    ent_coef        | 5.64e+06  |
# |    ent_coef_loss   | -0.122    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3610793   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.38e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90948     |
# |    fps             | 36        |
# |    time_elapsed    | 28        |
# |    total_timesteps | 3611030   |
# | train/             |           |
# |    actor_loss      | 1.67e+10  |
# |    critic_loss     | 1.27e+15  |
# |    ent_coef        | 5.58e+06  |
# |    ent_coef_loss   | 2.28      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3610929   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.44e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90952     |
# |    fps             | 36        |
# |    time_elapsed    | 31        |
# |    total_timesteps | 3611164   |
# | train/             |           |
# |    actor_loss      | 1.67e+10  |
# |    critic_loss     | 1.72e+15  |
# |    ent_coef        | 5.51e+06  |
# |    ent_coef_loss   | -3.17     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3611063   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.36e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90956     |
# |    fps             | 36        |
# |    time_elapsed    | 35        |
# |    total_timesteps | 3611296   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.36e+15  |
# |    ent_coef        | 5.46e+06  |
# |    ent_coef_loss   | -0.0627   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3611195   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.31e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90960     |
# |    fps             | 36        |
# |    time_elapsed    | 38        |
# |    total_timesteps | 3611432   |
# | train/             |           |
# |    actor_loss      | 1.66e+10  |
# |    critic_loss     | 1.25e+15  |
# |    ent_coef        | 5.38e+06  |
# |    ent_coef_loss   | 0.415     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3611331   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.28e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90964     |
# |    fps             | 36        |
# |    time_elapsed    | 42        |
# |    total_timesteps | 3611571   |
# | train/             |           |
# |    actor_loss      | 1.67e+10  |
# |    critic_loss     | 1.12e+15  |
# |    ent_coef        | 5.35e+06  |
# |    ent_coef_loss   | -1.06     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3611470   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.2      |
# |    ep_rew_mean     | -5.29e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90968     |
# |    fps             | 36        |
# |    time_elapsed    | 46        |
# |    total_timesteps | 3611705   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.28e+15  |
# |    ent_coef        | 5.31e+06  |
# |    ent_coef_loss   | 0.783     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3611604   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.3      |
# |    ep_rew_mean     | -5.31e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90972     |
# |    fps             | 37        |
# |    time_elapsed    | 49        |
# |    total_timesteps | 3611840   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.53e+15  |
# |    ent_coef        | 5.23e+06  |
# |    ent_coef_loss   | 1.8       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3611739   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.3      |
# |    ep_rew_mean     | -5.29e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90976     |
# |    fps             | 37        |
# |    time_elapsed    | 53        |
# |    total_timesteps | 3611977   |
# | train/             |           |
# |    actor_loss      | 1.67e+10  |
# |    critic_loss     | 1.13e+15  |
# |    ent_coef        | 5.19e+06  |
# |    ent_coef_loss   | -0.503    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3611876   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.4      |
# |    ep_rew_mean     | -5.32e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90980     |
# |    fps             | 37        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 3612114   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.64e+15  |
# |    ent_coef        | 5.18e+06  |
# |    ent_coef_loss   | -0.1      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612013   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.3      |
# |    ep_rew_mean     | -5.23e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90984     |
# |    fps             | 37        |
# |    time_elapsed    | 60        |
# |    total_timesteps | 3612247   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.76e+15  |
# |    ent_coef        | 5.16e+06  |
# |    ent_coef_loss   | 1.98      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612146   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.4      |
# |    ep_rew_mean     | -5.26e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90988     |
# |    fps             | 37        |
# |    time_elapsed    | 64        |
# |    total_timesteps | 3612386   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.53e+15  |
# |    ent_coef        | 5.16e+06  |
# |    ent_coef_loss   | 4.16      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612285   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.4      |
# |    ep_rew_mean     | -5.32e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90992     |
# |    fps             | 37        |
# |    time_elapsed    | 68        |
# |    total_timesteps | 3612522   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.66e+15  |
# |    ent_coef        | 5.16e+06  |
# |    ent_coef_loss   | -1.78     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612421   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.5      |
# |    ep_rew_mean     | -5.47e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 90996     |
# |    fps             | 37        |
# |    time_elapsed    | 71        |
# |    total_timesteps | 3612662   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.49e+15  |
# |    ent_coef        | 5.16e+06  |
# |    ent_coef_loss   | 2.76      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612561   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.6      |
# |    ep_rew_mean     | -5.54e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91000     |
# |    fps             | 37        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 3612797   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.27e+15  |
# |    ent_coef        | 5.15e+06  |
# |    ent_coef_loss   | -2.26     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612696   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.6      |
# |    ep_rew_mean     | -5.58e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91004     |
# |    fps             | 37        |
# |    time_elapsed    | 79        |
# |    total_timesteps | 3612933   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.58e+15  |
# |    ent_coef        | 5.18e+06  |
# |    ent_coef_loss   | -5.27     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612832   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.7      |
# |    ep_rew_mean     | -5.63e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91008     |
# |    fps             | 37        |
# |    time_elapsed    | 82        |
# |    total_timesteps | 3613071   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.57e+15  |
# |    ent_coef        | 5.18e+06  |
# |    ent_coef_loss   | 1.57      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3612970   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.7      |
# |    ep_rew_mean     | -5.64e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91012     |
# |    fps             | 37        |
# |    time_elapsed    | 86        |
# |    total_timesteps | 3613206   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.33e+15  |
# |    ent_coef        | 5.17e+06  |
# |    ent_coef_loss   | -2.34     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3613105   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.8      |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91016     |
# |    fps             | 37        |
# |    time_elapsed    | 90        |
# |    total_timesteps | 3613346   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.55e+15  |
# |    ent_coef        | 5.17e+06  |
# |    ent_coef_loss   | -0.608    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3613245   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.8      |
# |    ep_rew_mean     | -5.77e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91020     |
# |    fps             | 37        |
# |    time_elapsed    | 93        |
# |    total_timesteps | 3613483   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 9.94e+14  |
# |    ent_coef        | 5.17e+06  |
# |    ent_coef_loss   | -2.47     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3613382   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 33.9      |
# |    ep_rew_mean     | -5.82e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91024     |
# |    fps             | 37        |
# |    time_elapsed    | 97        |
# |    total_timesteps | 3613621   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.8e+15   |
# |    ent_coef        | 5.19e+06  |
# |    ent_coef_loss   | -0.403    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3613520   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34        |
# |    ep_rew_mean     | -5.85e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91028     |
# |    fps             | 37        |
# |    time_elapsed    | 101       |
# |    total_timesteps | 3613758   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1e+15     |
# |    ent_coef        | 5.19e+06  |
# |    ent_coef_loss   | 0.57      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3613657   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34        |
# |    ep_rew_mean     | -5.84e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91032     |
# |    fps             | 37        |
# |    time_elapsed    | 105       |
# |    total_timesteps | 3613895   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.12e+15  |
# |    ent_coef        | 5.2e+06   |
# |    ent_coef_loss   | -1.09     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3613794   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.1      |
# |    ep_rew_mean     | -5.88e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91036     |
# |    fps             | 37        |
# |    time_elapsed    | 108       |
# |    total_timesteps | 3614035   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 2.64e+15  |
# |    ent_coef        | 5.2e+06   |
# |    ent_coef_loss   | 2.77      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3613934   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.1      |
# |    ep_rew_mean     | -5.88e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91040     |
# |    fps             | 37        |
# |    time_elapsed    | 112       |
# |    total_timesteps | 3614172   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.29e+15  |
# |    ent_coef        | 5.22e+06  |
# |    ent_coef_loss   | 4.69      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3614071   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.1      |
# |    ep_rew_mean     | -5.89e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91044     |
# |    fps             | 37        |
# |    time_elapsed    | 116       |
# |    total_timesteps | 3614309   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.34e+15  |
# |    ent_coef        | 5.22e+06  |
# |    ent_coef_loss   | 2.06      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3614208   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.2      |
# |    ep_rew_mean     | -5.85e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91048     |
# |    fps             | 37        |
# |    time_elapsed    | 120       |
# |    total_timesteps | 3614448   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.57e+15  |
# |    ent_coef        | 5.24e+06  |
# |    ent_coef_loss   | -0.551    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3614347   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.2      |
# |    ep_rew_mean     | -5.84e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91052     |
# |    fps             | 37        |
# |    time_elapsed    | 123       |
# |    total_timesteps | 3614588   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.36e+15  |
# |    ent_coef        | 5.26e+06  |
# |    ent_coef_loss   | -1.09     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3614487   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.3      |
# |    ep_rew_mean     | -5.92e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91056     |
# |    fps             | 37        |
# |    time_elapsed    | 127       |
# |    total_timesteps | 3614728   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.2e+15   |
# |    ent_coef        | 5.27e+06  |
# |    ent_coef_loss   | -0.923    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3614627   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.3      |
# |    ep_rew_mean     | -5.88e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91060     |
# |    fps             | 37        |
# |    time_elapsed    | 131       |
# |    total_timesteps | 3614865   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.5e+15   |
# |    ent_coef        | 5.28e+06  |
# |    ent_coef_loss   | -2.12     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3614764   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.3      |
# |    ep_rew_mean     | -5.84e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91064     |
# |    fps             | 37        |
# |    time_elapsed    | 135       |
# |    total_timesteps | 3615003   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 1.11e+15  |
# |    ent_coef        | 5.32e+06  |
# |    ent_coef_loss   | -2.06     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3614902   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.89e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91068     |
# |    fps             | 37        |
# |    time_elapsed    | 138       |
# |    total_timesteps | 3615144   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.64e+15  |
# |    ent_coef        | 5.34e+06  |
# |    ent_coef_loss   | 4.8       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3615043   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.88e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91072     |
# |    fps             | 37        |
# |    time_elapsed    | 142       |
# |    total_timesteps | 3615282   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.13e+15  |
# |    ent_coef        | 5.35e+06  |
# |    ent_coef_loss   | 0.193     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3615181   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.92e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91076     |
# |    fps             | 36        |
# |    time_elapsed    | 146       |
# |    total_timesteps | 3615417   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.7e+15   |
# |    ent_coef        | 5.34e+06  |
# |    ent_coef_loss   | 1.05      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3615316   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.89e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91080     |
# |    fps             | 36        |
# |    time_elapsed    | 150       |
# |    total_timesteps | 3615555   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.4e+15   |
# |    ent_coef        | 5.35e+06  |
# |    ent_coef_loss   | 5.57      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3615454   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.94e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91084     |
# |    fps             | 36        |
# |    time_elapsed    | 153       |
# |    total_timesteps | 3615692   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.13e+15  |
# |    ent_coef        | 5.35e+06  |
# |    ent_coef_loss   | 1.02      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3615591   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -5.9e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 91088    |
# |    fps             | 36       |
# |    time_elapsed    | 157      |
# |    total_timesteps | 3615831  |
# | train/             |          |
# |    actor_loss      | 1.7e+10  |
# |    critic_loss     | 1.41e+15 |
# |    ent_coef        | 5.35e+06 |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3615730  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.84e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91092     |
# |    fps             | 36        |
# |    time_elapsed    | 161       |
# |    total_timesteps | 3615966   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.5e+15   |
# |    ent_coef        | 5.33e+06  |
# |    ent_coef_loss   | -2.4      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3615865   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.75e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91096     |
# |    fps             | 36        |
# |    time_elapsed    | 165       |
# |    total_timesteps | 3616102   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.65e+15  |
# |    ent_coef        | 5.33e+06  |
# |    ent_coef_loss   | -3.29     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3616001   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.67e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91100     |
# |    fps             | 36        |
# |    time_elapsed    | 168       |
# |    total_timesteps | 3616238   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.62e+15  |
# |    ent_coef        | 5.33e+06  |
# |    ent_coef_loss   | -4.47     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3616137   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -5.7e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 91104    |
# |    fps             | 36       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 3616377  |
# | train/             |          |
# |    actor_loss      | 1.69e+10 |
# |    critic_loss     | 1.9e+15  |
# |    ent_coef        | 5.31e+06 |
# |    ent_coef_loss   | -2.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3616276  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.67e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91108     |
# |    fps             | 36        |
# |    time_elapsed    | 176       |
# |    total_timesteps | 3616514   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.33e+15  |
# |    ent_coef        | 5.31e+06  |
# |    ent_coef_loss   | 1.31      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3616413   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -5.7e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 91112    |
# |    fps             | 36       |
# |    time_elapsed    | 180      |
# |    total_timesteps | 3616653  |
# | train/             |          |
# |    actor_loss      | 1.7e+10  |
# |    critic_loss     | 1.89e+15 |
# |    ent_coef        | 5.31e+06 |
# |    ent_coef_loss   | 2.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3616552  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.65e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91116     |
# |    fps             | 36        |
# |    time_elapsed    | 183       |
# |    total_timesteps | 3616789   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 3.09e+15  |
# |    ent_coef        | 5.31e+06  |
# |    ent_coef_loss   | -1.91     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3616688   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.69e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91120     |
# |    fps             | 36        |
# |    time_elapsed    | 187       |
# |    total_timesteps | 3616928   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.27e+15  |
# |    ent_coef        | 5.33e+06  |
# |    ent_coef_loss   | 0.755     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3616827   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.69e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91124     |
# |    fps             | 36        |
# |    time_elapsed    | 191       |
# |    total_timesteps | 3617066   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 3.4e+15   |
# |    ent_coef        | 5.3e+06   |
# |    ent_coef_loss   | -0.633    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3616965   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.5     |
# |    ep_rew_mean     | -5.7e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 91128    |
# |    fps             | 36       |
# |    time_elapsed    | 195      |
# |    total_timesteps | 3617204  |
# | train/             |          |
# |    actor_loss      | 1.71e+10 |
# |    critic_loss     | 3.75e+15 |
# |    ent_coef        | 5.29e+06 |
# |    ent_coef_loss   | 4.52     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3617103  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.71e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91132     |
# |    fps             | 36        |
# |    time_elapsed    | 198       |
# |    total_timesteps | 3617340   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.48e+15  |
# |    ent_coef        | 5.28e+06  |
# |    ent_coef_loss   | -3.6      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3617239   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91136     |
# |    fps             | 36        |
# |    time_elapsed    | 202       |
# |    total_timesteps | 3617480   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.38e+15  |
# |    ent_coef        | 5.28e+06  |
# |    ent_coef_loss   | -2.53     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3617379   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.75e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91140     |
# |    fps             | 36        |
# |    time_elapsed    | 206       |
# |    total_timesteps | 3617618   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 3.57e+15  |
# |    ent_coef        | 5.28e+06  |
# |    ent_coef_loss   | -3.78     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3617517   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91144     |
# |    fps             | 36        |
# |    time_elapsed    | 210       |
# |    total_timesteps | 3617756   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.28e+15  |
# |    ent_coef        | 5.29e+06  |
# |    ent_coef_loss   | -0.647    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3617655   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.72e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91148     |
# |    fps             | 36        |
# |    time_elapsed    | 213       |
# |    total_timesteps | 3617890   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.54e+15  |
# |    ent_coef        | 5.29e+06  |
# |    ent_coef_loss   | 2.45      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3617789   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91152     |
# |    fps             | 36        |
# |    time_elapsed    | 217       |
# |    total_timesteps | 3618032   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.31e+15  |
# |    ent_coef        | 5.28e+06  |
# |    ent_coef_loss   | -2.14     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3617931   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.69e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91156     |
# |    fps             | 36        |
# |    time_elapsed    | 221       |
# |    total_timesteps | 3618170   |
# | train/             |           |
# |    actor_loss      | 1.68e+10  |
# |    critic_loss     | 2.64e+15  |
# |    ent_coef        | 5.26e+06  |
# |    ent_coef_loss   | -2.24     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3618069   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -5.7e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 91160    |
# |    fps             | 36       |
# |    time_elapsed    | 224      |
# |    total_timesteps | 3618307  |
# | train/             |          |
# |    actor_loss      | 1.71e+10 |
# |    critic_loss     | 1.43e+15 |
# |    ent_coef        | 5.27e+06 |
# |    ent_coef_loss   | 1.73     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3618206  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.74e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91164     |
# |    fps             | 36        |
# |    time_elapsed    | 228       |
# |    total_timesteps | 3618444   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 3.24e+15  |
# |    ent_coef        | 5.28e+06  |
# |    ent_coef_loss   | -0.796    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3618343   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.71e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91168     |
# |    fps             | 36        |
# |    time_elapsed    | 232       |
# |    total_timesteps | 3618583   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 4.14e+15  |
# |    ent_coef        | 5.31e+06  |
# |    ent_coef_loss   | -0.349    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3618482   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.79e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91172     |
# |    fps             | 36        |
# |    time_elapsed    | 236       |
# |    total_timesteps | 3618722   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.61e+15  |
# |    ent_coef        | 5.31e+06  |
# |    ent_coef_loss   | 0.277     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3618621   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -5.8e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 91176    |
# |    fps             | 36       |
# |    time_elapsed    | 239      |
# |    total_timesteps | 3618860  |
# | train/             |          |
# |    actor_loss      | 1.71e+10 |
# |    critic_loss     | 1.56e+15 |
# |    ent_coef        | 5.28e+06 |
# |    ent_coef_loss   | 2.3      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3618759  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.83e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91180     |
# |    fps             | 36        |
# |    time_elapsed    | 243       |
# |    total_timesteps | 3618997   |
# | train/             |           |
# |    actor_loss      | 1.72e+10  |
# |    critic_loss     | 1.3e+15   |
# |    ent_coef        | 5.25e+06  |
# |    ent_coef_loss   | 3.48      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3618896   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.88e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91184     |
# |    fps             | 36        |
# |    time_elapsed    | 247       |
# |    total_timesteps | 3619136   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.86e+15  |
# |    ent_coef        | 5.24e+06  |
# |    ent_coef_loss   | -1.67     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3619035   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.91e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91188     |
# |    fps             | 36        |
# |    time_elapsed    | 250       |
# |    total_timesteps | 3619273   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.29e+15  |
# |    ent_coef        | 5.22e+06  |
# |    ent_coef_loss   | -3.45     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3619172   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.98e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91192     |
# |    fps             | 36        |
# |    time_elapsed    | 254       |
# |    total_timesteps | 3619411   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 1.35e+15  |
# |    ent_coef        | 5.22e+06  |
# |    ent_coef_loss   | -0.377    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3619310   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -5.94e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91196     |
# |    fps             | 36        |
# |    time_elapsed    | 258       |
# |    total_timesteps | 3619546   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.46e+15  |
# |    ent_coef        | 5.2e+06   |
# |    ent_coef_loss   | -5.02     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3619445   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -5.97e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91200     |
# |    fps             | 36        |
# |    time_elapsed    | 261       |
# |    total_timesteps | 3619683   |
# | train/             |           |
# |    actor_loss      | 1.72e+10  |
# |    critic_loss     | 1.91e+15  |
# |    ent_coef        | 5.19e+06  |
# |    ent_coef_loss   | 0.869     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3619582   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -6.03e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91204     |
# |    fps             | 36        |
# |    time_elapsed    | 265       |
# |    total_timesteps | 3619821   |
# | train/             |           |
# |    actor_loss      | 1.71e+10  |
# |    critic_loss     | 2.57e+15  |
# |    ent_coef        | 5.2e+06   |
# |    ent_coef_loss   | -0.941    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3619720   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.5      |
# |    ep_rew_mean     | -6.06e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91208     |
# |    fps             | 36        |
# |    time_elapsed    | 269       |
# |    total_timesteps | 3619960   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 2.02e+15  |
# |    ent_coef        | 5.22e+06  |
# |    ent_coef_loss   | 2.17      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3619859   |
# ----------------------------------
# -629784584.325933
# diff_timesteps is  1
# Elasped time is (sec) 270.9291560649872
# Wrapping the env in a DummyVecEnv.
# Successfully loaded model from models/SAC_non_corr_no_delay/3610000.zip
# Logging to logs\SAC_model_non_corr_no_delay_0
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -6.04e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91212     |
# |    fps             | 37        |
# |    time_elapsed    | 2         |
# |    total_timesteps | 3620101   |
# | train/             |           |
# |    actor_loss      | 1.7e+10   |
# |    critic_loss     | 1.17e+15  |
# |    ent_coef        | 5.5e+06   |
# |    ent_coef_loss   | -3.73     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3620000   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.4      |
# |    ep_rew_mean     | -6.07e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 91216     |
# |    fps             | 36        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 3620238   |
# | train/             |           |
# |    actor_loss      | 1.69e+10  |
# |    critic_loss     | 1.46e+15  |
# |    ent_coef        | 5.56e+06  |
# |    ent_coef_loss   | 2.29      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3620137   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.4     |
# |    ep_rew_mean     | -6e+08   |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 91220    |
# |    fps             | 36       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3620371  |
# | train/             |          |
# |    actor_loss      | 1.7e+10  |
# |    critic_loss     | 1.53e+15 |
# |    ent_coef        | 5.55e+06 |
# ...
# |    ent_coef        | 9.05e+06  |
# |    ent_coef_loss   | -2.06     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3816317   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.11e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96552     |
# |    fps             | 3         |
# |    time_elapsed    | 2069      |
# |    total_timesteps | 3816560   |
# | train/             |           |
# |    actor_loss      | 2.61e+10  |
# |    critic_loss     | 8.72e+15  |
# |    ent_coef        | 9.11e+06  |
# |    ent_coef_loss   | -3.49     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3816459   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.5     |
# |    ep_rew_mean     | -6.1e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 96556    |
# |    fps             | 3        |
# |    time_elapsed    | 2073     |
# |    total_timesteps | 3816703  |
# | train/             |          |
# |    actor_loss      | 2.64e+10 |
# |    critic_loss     | 9.34e+15 |
# |    ent_coef        | 9.21e+06 |
# |    ent_coef_loss   | 0.0584   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3816602  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.15e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96560     |
# |    fps             | 3         |
# |    time_elapsed    | 2078      |
# |    total_timesteps | 3816845   |
# | train/             |           |
# |    actor_loss      | 2.62e+10  |
# |    critic_loss     | 1.07e+16  |
# |    ent_coef        | 9.21e+06  |
# |    ent_coef_loss   | -2.92     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3816744   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.11e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96564     |
# |    fps             | 3         |
# |    time_elapsed    | 2082      |
# |    total_timesteps | 3816987   |
# | train/             |           |
# |    actor_loss      | 2.63e+10  |
# |    critic_loss     | 9.46e+15  |
# |    ent_coef        | 9.19e+06  |
# |    ent_coef_loss   | -0.986    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3816886   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.19e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96568     |
# |    fps             | 3         |
# |    time_elapsed    | 2087      |
# |    total_timesteps | 3817129   |
# | train/             |           |
# |    actor_loss      | 2.61e+10  |
# |    critic_loss     | 1.04e+16  |
# |    ent_coef        | 9.21e+06  |
# |    ent_coef_loss   | -1.32     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3817028   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.5     |
# |    ep_rew_mean     | -6.2e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 96572    |
# |    fps             | 3        |
# |    time_elapsed    | 2091     |
# |    total_timesteps | 3817273  |
# | train/             |          |
# |    actor_loss      | 2.64e+10 |
# |    critic_loss     | 1.65e+16 |
# |    ent_coef        | 9.19e+06 |
# |    ent_coef_loss   | 3.53     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3817172  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.09e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96576     |
# |    fps             | 3         |
# |    time_elapsed    | 2095      |
# |    total_timesteps | 3817414   |
# | train/             |           |
# |    actor_loss      | 2.62e+10  |
# |    critic_loss     | 1.03e+16  |
# |    ent_coef        | 9.18e+06  |
# |    ent_coef_loss   | 2.04      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3817313   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.09e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96580     |
# |    fps             | 3         |
# |    time_elapsed    | 2100      |
# |    total_timesteps | 3817555   |
# | train/             |           |
# |    actor_loss      | 2.65e+10  |
# |    critic_loss     | 1.4e+16   |
# |    ent_coef        | 9.18e+06  |
# |    ent_coef_loss   | -0.218    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3817454   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.15e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96584     |
# |    fps             | 3         |
# |    time_elapsed    | 2104      |
# |    total_timesteps | 3817697   |
# | train/             |           |
# |    actor_loss      | 2.64e+10  |
# |    critic_loss     | 1.1e+16   |
# |    ent_coef        | 9.15e+06  |
# |    ent_coef_loss   | -2.1      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3817596   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.11e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96588     |
# |    fps             | 3         |
# |    time_elapsed    | 2109      |
# |    total_timesteps | 3817838   |
# | train/             |           |
# |    actor_loss      | 2.61e+10  |
# |    critic_loss     | 8.01e+15  |
# |    ent_coef        | 9.2e+06   |
# |    ent_coef_loss   | 0.657     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3817737   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.5      |
# |    ep_rew_mean     | -6.08e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96592     |
# |    fps             | 3         |
# |    time_elapsed    | 2113      |
# |    total_timesteps | 3817977   |
# | train/             |           |
# |    actor_loss      | 2.63e+10  |
# |    critic_loss     | 9.7e+15   |
# |    ent_coef        | 9.22e+06  |
# |    ent_coef_loss   | 0.934     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3817876   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.4      |
# |    ep_rew_mean     | -6.02e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96596     |
# |    fps             | 3         |
# |    time_elapsed    | 2118      |
# |    total_timesteps | 3818116   |
# | train/             |           |
# |    actor_loss      | 2.64e+10  |
# |    critic_loss     | 1e+16     |
# |    ent_coef        | 9.29e+06  |
# |    ent_coef_loss   | 0.872     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3818015   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.4      |
# |    ep_rew_mean     | -6.03e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96600     |
# |    fps             | 3         |
# |    time_elapsed    | 2122      |
# |    total_timesteps | 3818258   |
# | train/             |           |
# |    actor_loss      | 2.63e+10  |
# |    critic_loss     | 1.08e+16  |
# |    ent_coef        | 9.28e+06  |
# |    ent_coef_loss   | 5.24      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3818157   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.4      |
# |    ep_rew_mean     | -6.02e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96604     |
# |    fps             | 3         |
# |    time_elapsed    | 2127      |
# |    total_timesteps | 3818400   |
# | train/             |           |
# |    actor_loss      | 2.63e+10  |
# |    critic_loss     | 9.41e+15  |
# |    ent_coef        | 9.3e+06   |
# |    ent_coef_loss   | -0.0198   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3818299   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.4      |
# |    ep_rew_mean     | -6.03e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96608     |
# |    fps             | 4         |
# |    time_elapsed    | 2132      |
# |    total_timesteps | 3818541   |
# | train/             |           |
# |    actor_loss      | 2.64e+10  |
# |    critic_loss     | 9.49e+15  |
# |    ent_coef        | 9.34e+06  |
# |    ent_coef_loss   | -1.49     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3818440   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.4      |
# |    ep_rew_mean     | -5.96e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96612     |
# |    fps             | 4         |
# |    time_elapsed    | 2137      |
# |    total_timesteps | 3818682   |
# | train/             |           |
# |    actor_loss      | 2.64e+10  |
# |    critic_loss     | 9.93e+15  |
# |    ent_coef        | 9.35e+06  |
# |    ent_coef_loss   | -0.947    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3818581   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.4      |
# |    ep_rew_mean     | -5.83e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96616     |
# |    fps             | 4         |
# |    time_elapsed    | 2140      |
# |    total_timesteps | 3818821   |
# | train/             |           |
# |    actor_loss      | 2.66e+10  |
# |    critic_loss     | 1.08e+16  |
# |    ent_coef        | 9.37e+06  |
# |    ent_coef_loss   | -4        |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3818720   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.78e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96620     |
# |    fps             | 4         |
# |    time_elapsed    | 2145      |
# |    total_timesteps | 3818962   |
# | train/             |           |
# |    actor_loss      | 2.63e+10  |
# |    critic_loss     | 8.74e+15  |
# |    ent_coef        | 9.38e+06  |
# |    ent_coef_loss   | -1.74     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3818861   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.78e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96624     |
# |    fps             | 4         |
# |    time_elapsed    | 2150      |
# |    total_timesteps | 3819103   |
# | train/             |           |
# |    actor_loss      | 2.67e+10  |
# |    critic_loss     | 9.17e+15  |
# |    ent_coef        | 9.42e+06  |
# |    ent_coef_loss   | 3.91      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3819002   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.82e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96628     |
# |    fps             | 4         |
# |    time_elapsed    | 2153      |
# |    total_timesteps | 3819244   |
# | train/             |           |
# |    actor_loss      | 2.68e+10  |
# |    critic_loss     | 1.17e+16  |
# |    ent_coef        | 9.46e+06  |
# |    ent_coef_loss   | 3.34      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3819143   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.77e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96632     |
# |    fps             | 4         |
# |    time_elapsed    | 2158      |
# |    total_timesteps | 3819386   |
# | train/             |           |
# |    actor_loss      | 2.67e+10  |
# |    critic_loss     | 9.74e+15  |
# |    ent_coef        | 9.5e+06   |
# |    ent_coef_loss   | 0.988     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3819285   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.75e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96636     |
# |    fps             | 4         |
# |    time_elapsed    | 2162      |
# |    total_timesteps | 3819527   |
# | train/             |           |
# |    actor_loss      | 2.68e+10  |
# |    critic_loss     | 1.05e+16  |
# |    ent_coef        | 9.46e+06  |
# |    ent_coef_loss   | 1.47      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3819426   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.72e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96640     |
# |    fps             | 4         |
# |    time_elapsed    | 2166      |
# |    total_timesteps | 3819668   |
# | train/             |           |
# |    actor_loss      | 2.66e+10  |
# |    critic_loss     | 9.93e+15  |
# |    ent_coef        | 9.48e+06  |
# |    ent_coef_loss   | -1.52     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3819567   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.78e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96644     |
# |    fps             | 4         |
# |    time_elapsed    | 2170      |
# |    total_timesteps | 3819810   |
# | train/             |           |
# |    actor_loss      | 2.67e+10  |
# |    critic_loss     | 1.04e+16  |
# |    ent_coef        | 9.48e+06  |
# |    ent_coef_loss   | 1.76      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3819709   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.75e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 96648     |
# |    fps             | 4         |
# |    time_elapsed    | 2175      |
# |    total_timesteps | 3819951   |
# | train/             |           |
# |    actor_loss      | 2.68e+10  |
# |    critic_loss     | 1.14e+16  |
# |    ent_coef        | 9.48e+06  |
# |    ent_coef_loss   | 3.25      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3819850   |
# ----------------------------------
# -381296989.789663
# diff_timesteps is  21
# Elasped time is (sec) 8008.554353475571

# %% [markdown]
# ### SAC Non Corrective With Delay

# %%
# FIRST RUN 
#run_model(c1_non_corrective_pred_with_delay_env, "SAC", "SAC_model_non_corr_with_delay", "models/SAC_non_corr_with_delay", 1, 3600, True, sac_model_non_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
run_model(c1_non_corrective_pred_with_delay_env, "SAC", "SAC_model_non_corr_with_delay", "models/SAC_non_corr_with_delay", 10000, 12600, False,)
# Out:
# Wrapping the env in a DummyVecEnv.
# Successfully loaded model from models/SAC_non_corr_with_delay/2240000.zip
# Logging to logs\SAC_model_non_corr_with_delay_0
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.65e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72140     |
# |    fps             | 35        |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2250109   |
# | train/             |           |
# |    actor_loss      | 6.49e+10  |
# |    critic_loss     | 1.55e+16  |
# |    ent_coef        | 2.01e+07  |
# |    ent_coef_loss   | 3.89      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250008   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.79e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72144     |
# |    fps             | 32        |
# |    time_elapsed    | 6         |
# |    total_timesteps | 2250219   |
# | train/             |           |
# |    actor_loss      | 6.53e+10  |
# |    critic_loss     | 1.68e+16  |
# |    ent_coef        | 1.99e+07  |
# |    ent_coef_loss   | 3.73      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250118   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.91e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72148     |
# |    fps             | 33        |
# |    time_elapsed    | 9         |
# |    total_timesteps | 2250329   |
# | train/             |           |
# |    actor_loss      | 6.52e+10  |
# |    critic_loss     | 1.68e+16  |
# |    ent_coef        | 1.98e+07  |
# |    ent_coef_loss   | -1.01     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250228   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.98e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72152     |
# |    fps             | 32        |
# |    time_elapsed    | 13        |
# |    total_timesteps | 2250439   |
# | train/             |           |
# |    actor_loss      | 6.53e+10  |
# |    critic_loss     | 1.54e+16  |
# |    ent_coef        | 1.99e+07  |
# |    ent_coef_loss   | 1.83      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250338   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.84e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72156     |
# |    fps             | 33        |
# |    time_elapsed    | 16        |
# |    total_timesteps | 2250547   |
# | train/             |           |
# |    actor_loss      | 6.56e+10  |
# |    critic_loss     | 1.89e+16  |
# |    ent_coef        | 2.01e+07  |
# |    ent_coef_loss   | -0.58     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250446   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.79e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72160     |
# |    fps             | 32        |
# |    time_elapsed    | 19        |
# |    total_timesteps | 2250656   |
# | train/             |           |
# |    actor_loss      | 6.55e+10  |
# |    critic_loss     | 2.02e+16  |
# |    ent_coef        | 2.03e+07  |
# |    ent_coef_loss   | -2.76     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250555   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72164     |
# |    fps             | 33        |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2250765   |
# | train/             |           |
# |    actor_loss      | 6.53e+10  |
# |    critic_loss     | 1.92e+16  |
# |    ent_coef        | 2.05e+07  |
# |    ent_coef_loss   | -1.94     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250664   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.55e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72168     |
# |    fps             | 32        |
# |    time_elapsed    | 26        |
# |    total_timesteps | 2250874   |
# | train/             |           |
# |    actor_loss      | 6.55e+10  |
# |    critic_loss     | 1.66e+16  |
# |    ent_coef        | 2.08e+07  |
# |    ent_coef_loss   | 0.795     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250773   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.49e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72172     |
# |    fps             | 32        |
# |    time_elapsed    | 29        |
# |    total_timesteps | 2250982   |
# | train/             |           |
# |    actor_loss      | 6.57e+10  |
# |    critic_loss     | 1.52e+16  |
# |    ent_coef        | 2.1e+07   |
# |    ent_coef_loss   | -0.707    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2250881   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.4e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72176    |
# |    fps             | 32       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2251091  |
# | train/             |          |
# |    actor_loss      | 6.57e+10 |
# |    critic_loss     | 1.72e+16 |
# |    ent_coef        | 2.12e+07 |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2250990  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.33e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72180     |
# |    fps             | 32        |
# |    time_elapsed    | 36        |
# |    total_timesteps | 2251199   |
# | train/             |           |
# |    actor_loss      | 6.55e+10  |
# |    critic_loss     | 2.04e+16  |
# |    ent_coef        | 2.13e+07  |
# |    ent_coef_loss   | 1.2       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2251098   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.3e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72184    |
# |    fps             | 32       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 2251309  |
# | train/             |          |
# |    actor_loss      | 6.57e+10 |
# |    critic_loss     | 1.6e+16  |
# |    ent_coef        | 2.16e+07 |
# |    ent_coef_loss   | 0.507    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2251208  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.31e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72188     |
# |    fps             | 32        |
# |    time_elapsed    | 43        |
# |    total_timesteps | 2251419   |
# | train/             |           |
# |    actor_loss      | 6.56e+10  |
# |    critic_loss     | 1.55e+16  |
# |    ent_coef        | 2.18e+07  |
# |    ent_coef_loss   | -3.02     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2251318   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.27e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72192     |
# |    fps             | 32        |
# |    time_elapsed    | 47        |
# |    total_timesteps | 2251528   |
# | train/             |           |
# |    actor_loss      | 6.59e+10  |
# |    critic_loss     | 1.94e+16  |
# |    ent_coef        | 2.2e+07   |
# |    ent_coef_loss   | 2.06      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2251427   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -5.2e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72196    |
# |    fps             | 32       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 2251637  |
# | train/             |          |
# |    actor_loss      | 6.5e+10  |
# |    critic_loss     | 1.67e+16 |
# |    ent_coef        | 2.22e+07 |
# |    ent_coef_loss   | 2.74     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2251536  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.16e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72200     |
# |    fps             | 32        |
# |    time_elapsed    | 53        |
# |    total_timesteps | 2251746   |
# | train/             |           |
# |    actor_loss      | 6.59e+10  |
# |    critic_loss     | 1.83e+16  |
# |    ent_coef        | 2.23e+07  |
# |    ent_coef_loss   | 2.96      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2251645   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.11e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72204     |
# |    fps             | 32        |
# |    time_elapsed    | 56        |
# |    total_timesteps | 2251856   |
# | train/             |           |
# |    actor_loss      | 6.56e+10  |
# |    critic_loss     | 1.56e+16  |
# |    ent_coef        | 2.24e+07  |
# |    ent_coef_loss   | -3.39     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2251755   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.09e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72208     |
# |    fps             | 32        |
# |    time_elapsed    | 61        |
# |    total_timesteps | 2251966   |
# | train/             |           |
# |    actor_loss      | 6.59e+10  |
# |    critic_loss     | 1.87e+16  |
# |    ent_coef        | 2.26e+07  |
# |    ent_coef_loss   | -3        |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2251865   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.22e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72212     |
# |    fps             | 32        |
# |    time_elapsed    | 64        |
# |    total_timesteps | 2252076   |
# | train/             |           |
# |    actor_loss      | 6.56e+10  |
# |    critic_loss     | 1.63e+16  |
# |    ent_coef        | 2.27e+07  |
# |    ent_coef_loss   | -4.59     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2251975   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.24e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72216     |
# |    fps             | 32        |
# |    time_elapsed    | 67        |
# |    total_timesteps | 2252187   |
# | train/             |           |
# |    actor_loss      | 6.63e+10  |
# |    critic_loss     | 1.96e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | -1.17     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2252086   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.19e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72220     |
# |    fps             | 32        |
# |    time_elapsed    | 70        |
# |    total_timesteps | 2252295   |
# | train/             |           |
# |    actor_loss      | 6.59e+10  |
# |    critic_loss     | 1.63e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | -2.76     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2252194   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.21e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72224     |
# |    fps             | 32        |
# |    time_elapsed    | 73        |
# |    total_timesteps | 2252405   |
# | train/             |           |
# |    actor_loss      | 6.61e+10  |
# |    critic_loss     | 2.05e+16  |
# |    ent_coef        | 2.29e+07  |
# |    ent_coef_loss   | 4.62      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2252304   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.09e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72228     |
# |    fps             | 32        |
# |    time_elapsed    | 77        |
# |    total_timesteps | 2252513   |
# | train/             |           |
# |    actor_loss      | 6.65e+10  |
# |    critic_loss     | 2.08e+16  |
# |    ent_coef        | 2.29e+07  |
# |    ent_coef_loss   | 4.66      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2252412   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -5e+08   |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72232    |
# |    fps             | 32       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 2252622  |
# | train/             |          |
# |    actor_loss      | 6.63e+10 |
# |    critic_loss     | 1.69e+16 |
# |    ent_coef        | 2.3e+07  |
# |    ent_coef_loss   | -2.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2252521  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -5e+08   |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72236    |
# |    fps             | 31       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 2252731  |
# | train/             |          |
# |    actor_loss      | 6.58e+10 |
# |    critic_loss     | 1.91e+16 |
# |    ent_coef        | 2.3e+07  |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2252630  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.01e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72240     |
# |    fps             | 32        |
# |    time_elapsed    | 88        |
# |    total_timesteps | 2252840   |
# | train/             |           |
# |    actor_loss      | 6.63e+10  |
# |    critic_loss     | 1.91e+16  |
# |    ent_coef        | 2.29e+07  |
# |    ent_coef_loss   | 3.2       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2252739   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -5e+08   |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72244    |
# |    fps             | 31       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 2252950  |
# | train/             |          |
# |    actor_loss      | 6.58e+10 |
# |    critic_loss     | 2.04e+16 |
# |    ent_coef        | 2.28e+07 |
# |    ent_coef_loss   | 1.66     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2252849  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -4.93e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72248     |
# |    fps             | 32        |
# |    time_elapsed    | 95        |
# |    total_timesteps | 2253059   |
# | train/             |           |
# |    actor_loss      | 6.6e+10   |
# |    critic_loss     | 2e+16     |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | 2.02      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2252958   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -4.93e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72252     |
# |    fps             | 32        |
# |    time_elapsed    | 98        |
# |    total_timesteps | 2253169   |
# | train/             |           |
# |    actor_loss      | 6.62e+10  |
# |    critic_loss     | 2.12e+16  |
# |    ent_coef        | 2.27e+07  |
# |    ent_coef_loss   | -3.19     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253068   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -4.97e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72256     |
# |    fps             | 32        |
# |    time_elapsed    | 101       |
# |    total_timesteps | 2253278   |
# | train/             |           |
# |    actor_loss      | 6.7e+10   |
# |    critic_loss     | 1.58e+16  |
# |    ent_coef        | 2.26e+07  |
# |    ent_coef_loss   | -5.04     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253177   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.03e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72260     |
# |    fps             | 32        |
# |    time_elapsed    | 104       |
# |    total_timesteps | 2253388   |
# | train/             |           |
# |    actor_loss      | 6.58e+10  |
# |    critic_loss     | 1.63e+16  |
# |    ent_coef        | 2.26e+07  |
# |    ent_coef_loss   | 0.937     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253287   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.17e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72264     |
# |    fps             | 32        |
# |    time_elapsed    | 108       |
# |    total_timesteps | 2253499   |
# | train/             |           |
# |    actor_loss      | 6.61e+10  |
# |    critic_loss     | 2.22e+16  |
# |    ent_coef        | 2.25e+07  |
# |    ent_coef_loss   | 1.91      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253398   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.13e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72268     |
# |    fps             | 32        |
# |    time_elapsed    | 111       |
# |    total_timesteps | 2253607   |
# | train/             |           |
# |    actor_loss      | 6.59e+10  |
# |    critic_loss     | 1.96e+16  |
# |    ent_coef        | 2.23e+07  |
# |    ent_coef_loss   | -3.7      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253506   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.3      |
# |    ep_rew_mean     | -5.18e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72272     |
# |    fps             | 32        |
# |    time_elapsed    | 114       |
# |    total_timesteps | 2253716   |
# | train/             |           |
# |    actor_loss      | 6.59e+10  |
# |    critic_loss     | 2.2e+16   |
# |    ent_coef        | 2.23e+07  |
# |    ent_coef_loss   | -3.8      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253615   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.25e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72276     |
# |    fps             | 32        |
# |    time_elapsed    | 118       |
# |    total_timesteps | 2253826   |
# | train/             |           |
# |    actor_loss      | 6.66e+10  |
# |    critic_loss     | 2.18e+16  |
# |    ent_coef        | 2.24e+07  |
# |    ent_coef_loss   | 2.19      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253725   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.33e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72280     |
# |    fps             | 32        |
# |    time_elapsed    | 120       |
# |    total_timesteps | 2253935   |
# | train/             |           |
# |    actor_loss      | 6.67e+10  |
# |    critic_loss     | 1.93e+16  |
# |    ent_coef        | 2.24e+07  |
# |    ent_coef_loss   | 0.704     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2253834   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.4e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72284    |
# |    fps             | 32       |
# |    time_elapsed    | 124      |
# |    total_timesteps | 2254046  |
# | train/             |          |
# |    actor_loss      | 6.65e+10 |
# |    critic_loss     | 2.05e+16 |
# |    ent_coef        | 2.24e+07 |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2253945  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.34e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72288     |
# |    fps             | 32        |
# |    time_elapsed    | 127       |
# |    total_timesteps | 2254155   |
# | train/             |           |
# |    actor_loss      | 6.68e+10  |
# |    critic_loss     | 2.01e+16  |
# |    ent_coef        | 2.23e+07  |
# |    ent_coef_loss   | -5.47     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254054   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.34e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72292     |
# |    fps             | 32        |
# |    time_elapsed    | 131       |
# |    total_timesteps | 2254264   |
# | train/             |           |
# |    actor_loss      | 6.64e+10  |
# |    critic_loss     | 1.84e+16  |
# |    ent_coef        | 2.24e+07  |
# |    ent_coef_loss   | 0.523     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254163   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.47e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72296     |
# |    fps             | 32        |
# |    time_elapsed    | 134       |
# |    total_timesteps | 2254375   |
# | train/             |           |
# |    actor_loss      | 6.64e+10  |
# |    critic_loss     | 1.53e+16  |
# |    ent_coef        | 2.24e+07  |
# |    ent_coef_loss   | -0.347    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254274   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.54e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72300     |
# |    fps             | 32        |
# |    time_elapsed    | 138       |
# |    total_timesteps | 2254485   |
# | train/             |           |
# |    actor_loss      | 6.64e+10  |
# |    critic_loss     | 1.9e+16   |
# |    ent_coef        | 2.23e+07  |
# |    ent_coef_loss   | 0.604     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254384   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.53e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72304     |
# |    fps             | 32        |
# |    time_elapsed    | 141       |
# |    total_timesteps | 2254595   |
# | train/             |           |
# |    actor_loss      | 6.6e+10   |
# |    critic_loss     | 2.02e+16  |
# |    ent_coef        | 2.23e+07  |
# |    ent_coef_loss   | -3.38     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254494   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.5e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72308    |
# |    fps             | 32       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 2254704  |
# | train/             |          |
# |    actor_loss      | 6.66e+10 |
# |    critic_loss     | 1.98e+16 |
# |    ent_coef        | 2.24e+07 |
# |    ent_coef_loss   | -2.32    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2254603  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.51e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72312     |
# |    fps             | 32        |
# |    time_elapsed    | 148       |
# |    total_timesteps | 2254814   |
# | train/             |           |
# |    actor_loss      | 6.67e+10  |
# |    critic_loss     | 2e+16     |
# |    ent_coef        | 2.25e+07  |
# |    ent_coef_loss   | -1.88     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254713   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.41e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72316     |
# |    fps             | 32        |
# |    time_elapsed    | 151       |
# |    total_timesteps | 2254923   |
# | train/             |           |
# |    actor_loss      | 6.71e+10  |
# |    critic_loss     | 1.72e+16  |
# |    ent_coef        | 2.25e+07  |
# |    ent_coef_loss   | -0.571    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254822   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.58e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72320     |
# |    fps             | 32        |
# |    time_elapsed    | 154       |
# |    total_timesteps | 2255034   |
# | train/             |           |
# |    actor_loss      | 6.67e+10  |
# |    critic_loss     | 2.4e+16   |
# |    ent_coef        | 2.26e+07  |
# |    ent_coef_loss   | 1.3       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2254933   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.63e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72324     |
# |    fps             | 32        |
# |    time_elapsed    | 158       |
# |    total_timesteps | 2255145   |
# | train/             |           |
# |    actor_loss      | 6.72e+10  |
# |    critic_loss     | 1.86e+16  |
# |    ent_coef        | 2.26e+07  |
# |    ent_coef_loss   | -2.54     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2255044   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.68e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72328     |
# |    fps             | 32        |
# |    time_elapsed    | 161       |
# |    total_timesteps | 2255254   |
# | train/             |           |
# |    actor_loss      | 6.71e+10  |
# |    critic_loss     | 1.66e+16  |
# |    ent_coef        | 2.26e+07  |
# |    ent_coef_loss   | -5.42     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2255153   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.7e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72332    |
# |    fps             | 32       |
# |    time_elapsed    | 164      |
# |    total_timesteps | 2255363  |
# | train/             |          |
# |    actor_loss      | 6.72e+10 |
# |    critic_loss     | 2.13e+16 |
# |    ent_coef        | 2.26e+07 |
# |    ent_coef_loss   | 0.592    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2255262  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.69e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72336     |
# |    fps             | 32        |
# |    time_elapsed    | 167       |
# |    total_timesteps | 2255472   |
# | train/             |           |
# |    actor_loss      | 6.66e+10  |
# |    critic_loss     | 2.04e+16  |
# |    ent_coef        | 2.26e+07  |
# |    ent_coef_loss   | 3.89      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2255371   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.76e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72340     |
# |    fps             | 32        |
# |    time_elapsed    | 171       |
# |    total_timesteps | 2255582   |
# | train/             |           |
# |    actor_loss      | 6.73e+10  |
# |    critic_loss     | 2.35e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | 1.95      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2255481   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72344     |
# |    fps             | 32        |
# |    time_elapsed    | 175       |
# |    total_timesteps | 2255692   |
# | train/             |           |
# |    actor_loss      | 6.68e+10  |
# |    critic_loss     | 1.91e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | -2.97     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2255591   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.81e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72348     |
# |    fps             | 32        |
# |    time_elapsed    | 178       |
# |    total_timesteps | 2255802   |
# | train/             |           |
# |    actor_loss      | 6.66e+10  |
# |    critic_loss     | 1.98e+16  |
# |    ent_coef        | 2.27e+07  |
# |    ent_coef_loss   | -0.406    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2255701   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.81e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72352     |
# |    fps             | 32        |
# |    time_elapsed    | 182       |
# |    total_timesteps | 2255912   |
# | train/             |           |
# |    actor_loss      | 6.63e+10  |
# |    critic_loss     | 1.99e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | 0.755     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2255811   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.9e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72356    |
# |    fps             | 32       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 2256022  |
# | train/             |          |
# |    actor_loss      | 6.72e+10 |
# |    critic_loss     | 2.25e+16 |
# |    ent_coef        | 2.29e+07 |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2255921  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.8e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72360    |
# |    fps             | 32       |
# |    time_elapsed    | 189      |
# |    total_timesteps | 2256131  |
# | train/             |          |
# |    actor_loss      | 6.68e+10 |
# |    critic_loss     | 1.95e+16 |
# |    ent_coef        | 2.29e+07 |
# |    ent_coef_loss   | 0.868    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2256030  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.66e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72364     |
# |    fps             | 32        |
# |    time_elapsed    | 192       |
# |    total_timesteps | 2256240   |
# | train/             |           |
# |    actor_loss      | 6.72e+10  |
# |    critic_loss     | 2.11e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | -7.38     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256139   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.66e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72368     |
# |    fps             | 32        |
# |    time_elapsed    | 195       |
# |    total_timesteps | 2256348   |
# | train/             |           |
# |    actor_loss      | 6.74e+10  |
# |    critic_loss     | 1.96e+16  |
# |    ent_coef        | 2.29e+07  |
# |    ent_coef_loss   | -3.12     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256247   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.79e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72372     |
# |    fps             | 32        |
# |    time_elapsed    | 199       |
# |    total_timesteps | 2256459   |
# | train/             |           |
# |    actor_loss      | 6.77e+10  |
# |    critic_loss     | 1.77e+16  |
# |    ent_coef        | 2.29e+07  |
# |    ent_coef_loss   | 0.616     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256358   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.77e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72376     |
# |    fps             | 32        |
# |    time_elapsed    | 204       |
# |    total_timesteps | 2256569   |
# | train/             |           |
# |    actor_loss      | 6.75e+10  |
# |    critic_loss     | 2.08e+16  |
# |    ent_coef        | 2.29e+07  |
# |    ent_coef_loss   | -1.65     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256468   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.75e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72380     |
# |    fps             | 32        |
# |    time_elapsed    | 208       |
# |    total_timesteps | 2256678   |
# | train/             |           |
# |    actor_loss      | 6.72e+10  |
# |    critic_loss     | 2.02e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | -1.53     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256577   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.63e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72384     |
# |    fps             | 32        |
# |    time_elapsed    | 211       |
# |    total_timesteps | 2256787   |
# | train/             |           |
# |    actor_loss      | 6.7e+10   |
# |    critic_loss     | 2.1e+16   |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | 2.88      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256686   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.63e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72388     |
# |    fps             | 31        |
# |    time_elapsed    | 215       |
# |    total_timesteps | 2256896   |
# | train/             |           |
# |    actor_loss      | 6.73e+10  |
# |    critic_loss     | 2.23e+16  |
# |    ent_coef        | 2.28e+07  |
# |    ent_coef_loss   | 1.77      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256795   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.69e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72392     |
# |    fps             | 31        |
# |    time_elapsed    | 220       |
# |    total_timesteps | 2257006   |
# | train/             |           |
# |    actor_loss      | 6.75e+10  |
# |    critic_loss     | 2.09e+16  |
# |    ent_coef        | 2.3e+07   |
# |    ent_coef_loss   | -3.51     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2256905   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.56e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72396     |
# |    fps             | 31        |
# |    time_elapsed    | 225       |
# |    total_timesteps | 2257115   |
# | train/             |           |
# |    actor_loss      | 6.71e+10  |
# |    critic_loss     | 1.93e+16  |
# |    ent_coef        | 2.3e+07   |
# |    ent_coef_loss   | -4.67     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257014   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.55e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72400     |
# |    fps             | 31        |
# |    time_elapsed    | 228       |
# |    total_timesteps | 2257225   |
# | train/             |           |
# |    actor_loss      | 6.75e+10  |
# |    critic_loss     | 2.15e+16  |
# |    ent_coef        | 2.31e+07  |
# |    ent_coef_loss   | -0.719    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257124   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.42e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72404     |
# |    fps             | 31        |
# |    time_elapsed    | 232       |
# |    total_timesteps | 2257333   |
# | train/             |           |
# |    actor_loss      | 6.69e+10  |
# |    critic_loss     | 2.02e+16  |
# |    ent_coef        | 2.31e+07  |
# |    ent_coef_loss   | 1.51      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257232   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -5.4e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 72408    |
# |    fps             | 31       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 2257442  |
# | train/             |          |
# |    actor_loss      | 6.74e+10 |
# |    critic_loss     | 2.14e+16 |
# |    ent_coef        | 2.31e+07 |
# |    ent_coef_loss   | -2.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2257341  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.41e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72412     |
# |    fps             | 31        |
# |    time_elapsed    | 239       |
# |    total_timesteps | 2257552   |
# | train/             |           |
# |    actor_loss      | 6.75e+10  |
# |    critic_loss     | 2.1e+16   |
# |    ent_coef        | 2.31e+07  |
# |    ent_coef_loss   | -0.127    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257451   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.42e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72416     |
# |    fps             | 31        |
# |    time_elapsed    | 242       |
# |    total_timesteps | 2257661   |
# | train/             |           |
# |    actor_loss      | 6.74e+10  |
# |    critic_loss     | 2.24e+16  |
# |    ent_coef        | 2.31e+07  |
# |    ent_coef_loss   | -4.77     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257560   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.38e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72420     |
# |    fps             | 31        |
# |    time_elapsed    | 246       |
# |    total_timesteps | 2257771   |
# | train/             |           |
# |    actor_loss      | 6.75e+10  |
# |    critic_loss     | 2.21e+16  |
# |    ent_coef        | 2.32e+07  |
# |    ent_coef_loss   | 3.82      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257670   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.32e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72424     |
# |    fps             | 31        |
# |    time_elapsed    | 249       |
# |    total_timesteps | 2257881   |
# | train/             |           |
# |    actor_loss      | 6.82e+10  |
# |    critic_loss     | 2.16e+16  |
# |    ent_coef        | 2.31e+07  |
# |    ent_coef_loss   | 1.12      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257780   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.35e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72428     |
# |    fps             | 31        |
# |    time_elapsed    | 253       |
# |    total_timesteps | 2257990   |
# | train/             |           |
# |    actor_loss      | 6.83e+10  |
# |    critic_loss     | 2.08e+16  |
# |    ent_coef        | 2.31e+07  |
# |    ent_coef_loss   | 0.139     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257889   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.39e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72432     |
# |    fps             | 31        |
# |    time_elapsed    | 257       |
# |    total_timesteps | 2258100   |
# | train/             |           |
# |    actor_loss      | 6.78e+10  |
# |    critic_loss     | 2.36e+16  |
# |    ent_coef        | 2.32e+07  |
# |    ent_coef_loss   | 0.234     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2257999   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.39e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72436     |
# |    fps             | 31        |
# |    time_elapsed    | 260       |
# |    total_timesteps | 2258209   |
# | train/             |           |
# |    actor_loss      | 6.73e+10  |
# |    critic_loss     | 1.8e+16   |
# |    ent_coef        | 2.32e+07  |
# |    ent_coef_loss   | -0.898    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2258108   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.37e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 72440     |
# |    fps             | 31        |
# |    time_elapsed    | 264       |
# |    total_timesteps | 2258319   |
# | train/             |           |
# |    actor_loss      | 6.83e+10  |
# |    critic_loss     | 2.12e+16  |
# |    ent_coef        | 2.32e+07  |
# |    ent_coef_loss   | 1.64      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2258218   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 27.4      |
# |    ep_rew_mean     | -5.26e+08 |
# |    phm_score       | 0         |
# ...
# |    ent_coef        | 4.74e+07  |
# |    ent_coef_loss   | -0.349    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2636305   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.3      |
# |    ep_rew_mean     | -5.74e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85260     |
# |    fps             | 38        |
# |    time_elapsed    | 170       |
# |    total_timesteps | 2636550   |
# | train/             |           |
# |    actor_loss      | 4.64e+10  |
# |    critic_loss     | 8.66e+16  |
# |    ent_coef        | 4.77e+07  |
# |    ent_coef_loss   | 1.43      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2636449   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.2      |
# |    ep_rew_mean     | -5.78e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85264     |
# |    fps             | 38        |
# |    time_elapsed    | 173       |
# |    total_timesteps | 2636688   |
# | train/             |           |
# |    actor_loss      | 4.68e+10  |
# |    critic_loss     | 8.13e+16  |
# |    ent_coef        | 4.76e+07  |
# |    ent_coef_loss   | 2.63      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2636587   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.1      |
# |    ep_rew_mean     | -5.75e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85268     |
# |    fps             | 38        |
# |    time_elapsed    | 177       |
# |    total_timesteps | 2636829   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 8.5e+16   |
# |    ent_coef        | 4.73e+07  |
# |    ent_coef_loss   | 0.912     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2636728   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35.1      |
# |    ep_rew_mean     | -5.68e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85272     |
# |    fps             | 38        |
# |    time_elapsed    | 180       |
# |    total_timesteps | 2636964   |
# | train/             |           |
# |    actor_loss      | 4.67e+10  |
# |    critic_loss     | 7.69e+16  |
# |    ent_coef        | 4.73e+07  |
# |    ent_coef_loss   | 1.86      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2636863   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35        |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85276     |
# |    fps             | 38        |
# |    time_elapsed    | 184       |
# |    total_timesteps | 2637104   |
# | train/             |           |
# |    actor_loss      | 4.68e+10  |
# |    critic_loss     | 8.13e+16  |
# |    ent_coef        | 4.75e+07  |
# |    ent_coef_loss   | -1.54     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2637003   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35       |
# |    ep_rew_mean     | -5.7e+08 |
# |    phm_score       | 0        |
# | time/              |          |
# |    episodes        | 85280    |
# |    fps             | 38       |
# |    time_elapsed    | 188      |
# |    total_timesteps | 2637249  |
# | train/             |          |
# |    actor_loss      | 4.64e+10 |
# |    critic_loss     | 6.65e+16 |
# |    ent_coef        | 4.74e+07 |
# |    ent_coef_loss   | 1.6      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2637148  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 35        |
# |    ep_rew_mean     | -5.67e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85284     |
# |    fps             | 38        |
# |    time_elapsed    | 191       |
# |    total_timesteps | 2637387   |
# | train/             |           |
# |    actor_loss      | 4.65e+10  |
# |    critic_loss     | 7.32e+16  |
# |    ent_coef        | 4.75e+07  |
# |    ent_coef_loss   | 0.417     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2637286   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.9      |
# |    ep_rew_mean     | -5.57e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85288     |
# |    fps             | 38        |
# |    time_elapsed    | 195       |
# |    total_timesteps | 2637526   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 1.06e+17  |
# |    ent_coef        | 4.75e+07  |
# |    ent_coef_loss   | -3.92     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2637425   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.9      |
# |    ep_rew_mean     | -5.56e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85292     |
# |    fps             | 38        |
# |    time_elapsed    | 198       |
# |    total_timesteps | 2637662   |
# | train/             |           |
# |    actor_loss      | 4.64e+10  |
# |    critic_loss     | 7.04e+16  |
# |    ent_coef        | 4.75e+07  |
# |    ent_coef_loss   | -3.73     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2637561   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.9      |
# |    ep_rew_mean     | -5.55e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85296     |
# |    fps             | 38        |
# |    time_elapsed    | 202       |
# |    total_timesteps | 2637803   |
# | train/             |           |
# |    actor_loss      | 4.65e+10  |
# |    critic_loss     | 7.62e+16  |
# |    ent_coef        | 4.74e+07  |
# |    ent_coef_loss   | 0.77      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2637702   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.9      |
# |    ep_rew_mean     | -5.61e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85300     |
# |    fps             | 38        |
# |    time_elapsed    | 205       |
# |    total_timesteps | 2637939   |
# | train/             |           |
# |    actor_loss      | 4.68e+10  |
# |    critic_loss     | 8.25e+16  |
# |    ent_coef        | 4.72e+07  |
# |    ent_coef_loss   | -0.0272   |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2637838   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.9      |
# |    ep_rew_mean     | -5.62e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85304     |
# |    fps             | 38        |
# |    time_elapsed    | 209       |
# |    total_timesteps | 2638076   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 8.08e+16  |
# |    ent_coef        | 4.72e+07  |
# |    ent_coef_loss   | 4.7       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2637975   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.63e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85308     |
# |    fps             | 38        |
# |    time_elapsed    | 214       |
# |    total_timesteps | 2638216   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 9.66e+16  |
# |    ent_coef        | 4.72e+07  |
# |    ent_coef_loss   | 0.292     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2638115   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.73e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85312     |
# |    fps             | 38        |
# |    time_elapsed    | 218       |
# |    total_timesteps | 2638354   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 8.2e+16   |
# |    ent_coef        | 4.71e+07  |
# |    ent_coef_loss   | 0.83      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2638253   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.78e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85316     |
# |    fps             | 38        |
# |    time_elapsed    | 223       |
# |    total_timesteps | 2638496   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 9.13e+16  |
# |    ent_coef        | 4.71e+07  |
# |    ent_coef_loss   | 2.91      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2638395   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.77e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85320     |
# |    fps             | 37        |
# |    time_elapsed    | 227       |
# |    total_timesteps | 2638636   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 8.05e+16  |
# |    ent_coef        | 4.71e+07  |
# |    ent_coef_loss   | -3.33     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2638535   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.7      |
# |    ep_rew_mean     | -5.77e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85324     |
# |    fps             | 0         |
# |    time_elapsed    | 43338     |
# |    total_timesteps | 2638768   |
# | train/             |           |
# |    actor_loss      | 4.63e+10  |
# |    critic_loss     | 9.29e+16  |
# |    ent_coef        | 4.72e+07  |
# |    ent_coef_loss   | 0.932     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2638667   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.7      |
# |    ep_rew_mean     | -5.81e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85328     |
# |    fps             | 0         |
# |    time_elapsed    | 43346     |
# |    total_timesteps | 2638908   |
# | train/             |           |
# |    actor_loss      | 4.63e+10  |
# |    critic_loss     | 7.04e+16  |
# |    ent_coef        | 4.71e+07  |
# |    ent_coef_loss   | 5.23      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2638807   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.74e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85332     |
# |    fps             | 0         |
# |    time_elapsed    | 43352     |
# |    total_timesteps | 2639052   |
# | train/             |           |
# |    actor_loss      | 4.66e+10  |
# |    critic_loss     | 6.29e+16  |
# |    ent_coef        | 4.71e+07  |
# |    ent_coef_loss   | 3.83      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2638951   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.74e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85336     |
# |    fps             | 0         |
# |    time_elapsed    | 43359     |
# |    total_timesteps | 2639193   |
# | train/             |           |
# |    actor_loss      | 4.63e+10  |
# |    critic_loss     | 7.12e+16  |
# |    ent_coef        | 4.72e+07  |
# |    ent_coef_loss   | -0.339    |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2639092   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.61e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85340     |
# |    fps             | 0         |
# |    time_elapsed    | 43366     |
# |    total_timesteps | 2639332   |
# | train/             |           |
# |    actor_loss      | 4.64e+10  |
# |    critic_loss     | 6.93e+16  |
# |    ent_coef        | 4.7e+07   |
# |    ent_coef_loss   | -4.81     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2639231   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.63e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85344     |
# |    fps             | 0         |
# |    time_elapsed    | 43373     |
# |    total_timesteps | 2639468   |
# | train/             |           |
# |    actor_loss      | 4.64e+10  |
# |    critic_loss     | 5.77e+16  |
# |    ent_coef        | 4.69e+07  |
# |    ent_coef_loss   | -4.3      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2639367   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.67e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85348     |
# |    fps             | 0         |
# |    time_elapsed    | 43377     |
# |    total_timesteps | 2639610   |
# | train/             |           |
# |    actor_loss      | 4.64e+10  |
# |    critic_loss     | 8.37e+16  |
# |    ent_coef        | 4.7e+07   |
# |    ent_coef_loss   | 2.64      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2639509   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.63e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85352     |
# |    fps             | 0         |
# |    time_elapsed    | 43381     |
# |    total_timesteps | 2639747   |
# | train/             |           |
# |    actor_loss      | 4.63e+10  |
# |    critic_loss     | 7.23e+16  |
# |    ent_coef        | 4.7e+07   |
# |    ent_coef_loss   | 4.1       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2639646   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 34.8      |
# |    ep_rew_mean     | -5.59e+08 |
# |    phm_score       | 0         |
# | time/              |           |
# |    episodes        | 85356     |
# |    fps             | 0         |
# |    time_elapsed    | 43386     |
# |    total_timesteps | 2639889   |
# | train/             |           |
# |    actor_loss      | 4.63e+10  |
# |    critic_loss     | 7.11e+16  |
# |    ent_coef        | 4.71e+07  |
# |    ent_coef_loss   | 2.55      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 2639788   |
# ----------------------------------
# -360335908.400252
# diff_timesteps is  39
# Elasped time is (sec) 53803.610602617264

# %% [markdown]
# ### SAC Corrective no Delay

# %%
# FIRST RUN 
#run_model(c1_corrective_pred_no_delay_env, "SAC", "SAC_model_corr_no_delay", "models/SAC_corr_no_delay", 1, 3600, True, sac_model_corr_no_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_corrective_pred_no_delay_env, "SAC", "SAC_model_corr_no_delay", "models/SAC_corr_no_delay", 10, 3600, False,)

# %% [markdown]
# ### SAC Corrective with Delay

# %%
# FIRST RUN 
#run_model(c1_corrective_pred_with_delay_env, "SAC", "SAC_model_corr_with_delay", "models/SAC_corr_with_delay", 1, 3600, True, sac_model_corr_with_delay) #1hour   
#-------------
# MAIN RUN 
#run_model(c1_corrective_pred_with_delay_env, "SAC", "SAC_model_corr_with_delay", "models/SAC_corr_with_delay", 10, 3600, False,)

# %% [markdown]
# # Evaluate policy

# %% [markdown]
# Evaluate_policy, returns the mean reward per episode and the standard deviation of the reward per episode
#
# -> The "mean reward per episode" represents the average reward obtained per episode over the evaluation period.
# -> The "standard deviation of the reward per episode" indicates how much the rewards vary from the mean reward per episode.

# %% [markdown]
# Default Evalueate Policy

# %%
#evaluate_policy(model_xyz , non_corrective_pred_env_c4 , n_eval_episodes=10, render=False)

# %% [markdown]
# **Πρεπει να φτιάξω μια συνάρτηση για τα non corrective environment**
#
# To πρόβλημα ποιο είναι ;
#
# Το πρόβλημα είναι ότι στα non corr env μπορεί να πέσω πάνω σε μοντέλο που δεν τερματίζει οπότε αξίζει να ψάξω
# ποιο τερματίζει και να χρησιμοποιήσω εκείνο.
#
# Σκέψου αναδρομικά πήγαινε προς τα πίσω μέχρι να βρεις κάποιο το οποίο τερματίζει. (Εάν δεν βρείς σταμάτα)

# %%
# Function to find the highest 'i' value from existing model files
def find_highest_i(models_dir):
    highest_i = 0
    for filename in os.listdir(models_dir):
        if filename.endswith(".zip"):  # Ensure we're only looking at model files
            try:
                # Extract 'i' from the filename based on the TIMESTEPS*i pattern
                i = int(filename.replace('.zip', '').split('/')[-1]) // TIMESTEPS
                if i > highest_i:
                    highest_i = i
            except ValueError:
                # In case the filename doesn't follow the expected pattern
                continue
    return highest_i

#=====================================================

def load_model(model_filename, algo, env):
    if Path(model_filename).exists():
        algo_class = getattr(stable_baselines3, algo)
        loaded_model = algo_class.load(model_filename, env)
        print(f"Successfully loaded model from {model_filename}")
        return loaded_model 
    else:
        print(f"Model file '{model_filename}' does not exist.")

# %%
def make_filename_i(models_dir, i): 
    if not os.path.exists(models_dir): 
        os.makedirs(models_dir)
        
    #highest_i = find_highest_i(models_dir)
    return f"{models_dir}/{TIMESTEPS*i}.zip"

# %%
import os
import sys
from contextlib import redirect_stdout
def find_314_non_corr(algo,  env, model_dir,  n_eval_episodes=1, render=False):
    
    reward_314_log = []
    phm_score_log = []  # keep all the phm_scores
    reward_timestep_log = []
    
    found = False
    reached_314 = False
    i = find_highest_i(model_dir)  #the latest trained model
    while not found :
            
        total_reward = 0.0
        #Load model at timestep i
        model_filename = make_filename_i(model_dir , i)
        #model = load_model(model_filename, algo , env)
        # Για να μην κάνει τόσα print
        with open(os.devnull, 'w') as fnull, redirect_stdout(fnull):
            model = load_model(model_filename, algo, env)
        
        for _ in range(n_eval_episodes):
            obs = env.reset()
            done = False
            episode_reward = 0.0
            phm_score = 0.0

            while not done:

                if render:
                    env.render()
                if isinstance(obs, tuple):  # Check if the observation is a tuple
                    obs = obs[0]  # If it is, extract the first element
                action, _ = model.predict(obs, deterministic=True)

                obs, reward, terminated, trunctated, info = env.step(action)
                episode_reward += reward
                #print(info)

                # Retrieve the cut information from the info dictionary
                current_step = info.get('cut', 0)
                phm_score = info.get('score', 0)
                #score_314 = info.get('score_314',0) # 0 is the default value assigned if the score_314 doesnt exist in the info dict
                
                #print(current_step, "-> " , score_314)
                #print(phm_score)
                #print("Current step is ", current_step, " AND the phm score is : " ,phm_score)

                if current_step > 313 :
                    
                    #print("Phm score is : ", phm_score)
                    #print("Reward is :", episode_reward)
                    
                    phm_score_log.append([phm_score, i])
                    reward_314_log.append([episode_reward, i])
                    reached_314 = True
                    done = True

                if terminated or trunctated : 
                    #print(current_step)
                    #print("Terminated is : ", terminated)
                    #print("Trunctuated is : ", trunctated)
                    done = True

            total_reward += episode_reward
            reward = total_reward / n_eval_episodes
            reward_timestep_log.append([reward, i])
        
        i = i-1
        if(i<=1): 
            if(reached_314 != True) : 
                print("-----------------------------------")
                print("No model has reached the cut '314' ")
                print("-----------------------------------")
            found = True 

    return reward_timestep_log, phm_score_log, reward_314_log

# %%
import matplotlib.pyplot as plt

arr = [1,2,3]

plt.plot(arr)

# %%
def print_results(reward_timestep_log, phm_score_log, reward_314_log) : 
    
    print()
    max_reward, timestep_i = max(reward_timestep_log, key=lambda entry: entry[0])
    print("Max Reward is : ", max_reward, " and it is found at timestep : ", timestep_i)

    if phm_score_log: 
        min_phm, timestep_i = min(phm_score_log, key=lambda entry: entry[0])
        print("Min Phm Score is : ", min_phm, " and it is found at timestep : ", timestep_i)
    
    if reward_314_log:
        max_reward_314, timestep_i =  max(reward_314_log, key=lambda entry: entry[0])
        print("Max Reward-314 is : ", max_reward_314, " and it is found at timestep : ", timestep_i)

# %%
max_reward, timestep_i = max(reward_timestep_log, key=lambda entry: entry[0])
print("Max Reward is : ", max_reward, " and it is found at timestep : ", timestep_i, " *10,000")

# %%
print("OG function ", evaluate_policy(ppo_model_non_corr_no_delay, c6_non_corrective_pred_no_delay_env, n_eval_episodes=10, render=False) )
evaluate_and_print_policy(ppo_model_non_corr_no_delay, c6_non_corrective_pred_no_delay_env, "PPO Non-Corr No Delay")

# %%
df_c1 = pd.read_csv("./normalised_time_domain_features_with_cut_and_flute_max.csv")
df_c4 = pd.read_csv("./normalised_time_domain_features_c4_with_cut_and_flute_max.csv")
df_c6 = pd.read_csv("./normalised_time_domain_features_c6_with_cut_and_flute_max.csv")

# %%
## -- CUTTER 1 -- ##
c1_non_corrective_pred_no_delay_env = Monitor(CNC_Env_Non_Corrective_No_Delay(df_c1), logdir)
c1_non_corrective_pred_with_delay_env = Monitor(CNC_Env_Non_Corrective_with_Delay(df_c1), logdir)
#------------------------
c1_corrective_pred_no_delay_env = Monitor(CNC_Env_Corrective_Pred_No_Delay(df_c1), logdir)
c1_corrective_pred_with_delay_env = Monitor(CNC_Env_Corrective_Pred_with_Delay(df_c1), logdir)

# -- CUTTER 2 -- ## 
c4_non_corrective_pred_no_delay_env = Monitor(CNC_Env_Non_Corrective_No_Delay(df_c4), logdir)
c4_non_corrective_pred_with_delay_env = Monitor(CNC_Env_Non_Corrective_with_Delay(df_c4), logdir)
#------------------------
c4_corrective_pred_no_delay_env = Monitor(CNC_Env_Corrective_Pred_No_Delay(df_c4), logdir)
c4_corrective_pred_with_delay_env = Monitor(CNC_Env_Corrective_Pred_with_Delay(df_c4), logdir)

# -- CUTTER 3 -- ## 
c6_non_corrective_pred_no_delay_env = Monitor(CNC_Env_Non_Corrective_No_Delay(df_c6), logdir)
c6_non_corrective_pred_with_delay_env = Monitor(CNC_Env_Non_Corrective_with_Delay(df_c6), logdir)
#------------------------
c6_corrective_pred_no_delay_env = Monitor(CNC_Env_Corrective_Pred_No_Delay(df_c6), logdir)
c6_corrective_pred_with_delay_env = Monitor(CNC_Env_Corrective_Pred_with_Delay(df_c6), logdir)

# %%
# Loading 

#PPO
model_filename = make_filename("models\PPO_non_corr_no_delay")
ppo_model_non_corr_no_delay = load_model(model_filename, "PPO", c1_non_corrective_pred_no_delay_env)
#-
model_filename = make_filename("models\PPO_non_corr_with_delay")
ppo_model_non_corr_with_delay = load_model(model_filename, "PPO", c1_non_corrective_pred_with_delay_env)
#-
model_filename = make_filename("models\PPO_corr_no_delay")
ppo_model_corr_no_delay = load_model(model_filename, "PPO", c1_corrective_pred_no_delay_env)
#-
model_filename = make_filename("models\PPO_corr_with_delay")
ppo_model_corr_with_delay = load_model(model_filename, "PPO", c1_corrective_pred_with_delay_env)
#------------------
#A2C
model_filename = make_filename("models\A2C_non_corr_no_delay")
a2c_model_non_corr_no_delay = load_model(model_filename, "A2C", c1_non_corrective_pred_no_delay_env) 
#-
model_filename = make_filename("models\A2C_non_corr_with_delay")
a2c_model_non_corr_with_delay = load_model(model_filename, "A2C", c1_non_corrective_pred_with_delay_env)
#-
model_filename = make_filename("models\A2C_corr_no_delay")
a2c_model_corr_no_delay = load_model(model_filename, "A2C", c1_corrective_pred_no_delay_env)
#-
model_filename = make_filename("models\A2C_corr_with_delay")
a2c_model_corr_with_delay = load_model(model_filename, "A2C", c1_corrective_pred_with_delay_env)
#------------------
#DDPG
model_filename = make_filename("models\DDPG_non_corr_no_delay")
ddpg_model_non_corr_no_delay = load_model(model_filename, "DDPG", c1_non_corrective_pred_no_delay_env)
#-
model_filename = make_filename("models\DDPG_non_corr_with_delay")
ddpg_model_non_corr_with_delay = load_model(model_filename, "DDPG", c1_non_corrective_pred_with_delay_env)
#-
model_filename = make_filename("models\DDPG_corr_no_delay")
ddpg_model_corr_no_delay = load_model(model_filename, "DDPG", c1_corrective_pred_no_delay_env)
#-
model_filename = make_filename("models\DDPG_corr_with_delay")
ddpg_model_corr_with_delay = load_model(model_filename, "DDPG", c1_corrective_pred_with_delay_env)
#------------------
#SAC
model_filename = make_filename("models\SAC_non_corr_no_delay")
sac_model_non_corr_no_delay = load_model(model_filename, "SAC", c1_non_corrective_pred_no_delay_env)
#-
model_filename = make_filename("models\SAC_non_corr_with_delay")
sac_model_non_corr_with_delay = load_model(model_filename, "SAC", c1_non_corrective_pred_with_delay_env)
#-
model_filename = make_filename("models\SAC_corr_no_delay")
sac_model_corr_no_delay = load_model(model_filename, "SAC", c1_corrective_pred_no_delay_env)
#-
model_filename = make_filename("models\SAC_corr_with_delay")
sac_model_corr_with_delay = load_model(model_filename, "SAC", c1_corrective_pred_with_delay_env)

# %%
def evaluate_policy_with_score(model, env, n_eval_episodes=10, render=False):
    total_reward = 0.0
    phm_score_log = []  # keep all the phm_scores
    for _ in range(n_eval_episodes):
        obs = env.reset()
        done = False
        episode_reward = 0.0
        phm_score = 0.0
        
        while not done:
            
            if render:
                env.render()
            if isinstance(obs, tuple):  # Check if the observation is a tuple
                obs = obs[0]  # If it is, extract the first element
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, trunctated, info = env.step(action)
            #print(info)
            episode_reward += reward
            # Retrieve the cut information from the info dictionary
            current_step = info.get('cut', 0)
            phm_score = info.get('score', 0)

            #print(episode_reward)
            print(phm_score) 
            # print(terminated, current_step, trunctated)
            print(current_step)
            if current_step > (MAX_STEPS - 10):
                # Assuming that the PHM score is the reward in this case
                print("hello")
                phm_score = info.get('score', 0)
                print(phm_score)
                phm_score_log.append(phm_score)
                done = True
                
            if terminated or trunctated : 
                done = True

        
        total_reward += episode_reward

    avg_reward = total_reward / n_eval_episodes
    return avg_reward, phm_score_log

# %%
def evaluate_and_print_policy(model, env, model_name):
    avg_reward, avg_phm_score = evaluate_policy_with_score(model, env, n_eval_episodes=1, render=False)
    print(f"{model_name} Evaluation:")
    print("Average Reward:", avg_reward)
    print("PHM Score:", avg_phm_score)
    return avg_reward, avg_phm_score

# %% [markdown]
# # Results

# %% [markdown]
# r = reward_timestep_log, <br>
# p = phm_score_log, <br>
# r_314 = reward_314_log <br>

# %% [markdown]
# # **PPO**

# %% [markdown]
# ### PPO Corr

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c4_corrective_pred_no_delay_env, model_dir="models\PPO_corr_no_delay" , )
print('\033[1m  PPO Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c6_corrective_pred_no_delay_env, model_dir="models\PPO_corr_no_delay" , )
print('\033[1m  PPO Corrective Env | No Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c4_corrective_pred_with_delay_env, model_dir="models\PPO_corr_with_delay" , )
print('\033[1m  PPO Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c6_corrective_pred_with_delay_env, model_dir="models\PPO_corr_with_delay" , )
print('\033[1m  PPO Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %% [markdown]
# ### PPO Non Corr

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c4_non_corrective_pred_no_delay_env, model_dir="models\PPO_non_corr_no_delay" ,)
print('\033[1m  PPO Non Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c6_non_corrective_pred_no_delay_env, model_dir="models\PPO_non_corr_no_delay" , )
print('\033[1m  PPO Non Corrective Env | No Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c4_non_corrective_pred_with_delay_env, model_dir="models\PPO_non_corr_with_delay" ,)
print('\033[1m  PPO Non Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="PPO", env=c6_non_corrective_pred_with_delay_env, model_dir="models\PPO_non_corr_with_delay" ,)
print('\033[1m  PPO Non Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %% [markdown]
# # **A2C**

# %% [markdown]
# ### A2C Corr

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c4_corrective_pred_no_delay_env, model_dir="models\A2C_corr_no_delay" , )
print('\033[1m  A2C Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c6_corrective_pred_no_delay_env, model_dir="models\A2C_corr_no_delay" , )
print('\033[1m  A2C Corrective Env | No Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c4_corrective_pred_with_delay_env, model_dir="models\A2C_corr_with_delay" , )
print('\033[1m  A2C Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c6_corrective_pred_with_delay_env, model_dir="models\A2C_corr_with_delay" , )
print('\033[1m  A2C Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %% [markdown]
# ### A2C Non Corr

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c4_non_corrective_pred_no_delay_env, model_dir="models\A2C_non_corr_no_delay" , )
print('\033[1m  A2C Non Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c6_non_corrective_pred_no_delay_env, model_dir="models\A2C_non_corr_no_delay" , )
print('\033[1m  A2C Non Corrective Env | No Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c4_non_corrective_pred_with_delay_env, model_dir="models\A2C_non_corr_with_delay" , )
print('\033[1m  A2C Non Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="A2C", env=c6_non_corrective_pred_with_delay_env, model_dir="models\A2C_non_corr_with_delay" , )
print('\033[1m  A2C Non Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %% [markdown]
# # **DDPG**

# %% [markdown]
# ### DDPG Corr

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c4_corrective_pred_no_delay_env, model_dir="models\DDPG_corr_no_delay" , )
print('\033[1m  DDPG Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c6_corrective_pred_no_delay_env, model_dir="models\DDPG_corr_no_delay" , )
print('\033[1m  DDPG Corrective Env | No Delay | Cutter 6A\033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c4_corrective_pred_with_delay_env, model_dir="models\DDPG_corr_with_delay" , )
print('\033[1m  DDPG Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c6_corrective_pred_with_delay_env, model_dir="models\DDPG_corr_with_delay" , )
print('\033[1m  DDPG Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %% [markdown]
# ### DDPG Non Corr

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c4_non_corrective_pred_no_delay_env, model_dir="models\DDPG_non_corr_no_delay" , )
print('\033[1m  DDPG Non Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c6_non_corrective_pred_no_delay_env, model_dir="models\DDPG_non_corr_no_delay" , )
print('\033[1m  DDPG Non Corrective Env | No Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c4_non_corrective_pred_with_delay_env, model_dir="models\DDPG_non_corr_with_delay" , )
print('\033[1m  DDPG Non Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="DDPG", env=c6_non_corrective_pred_with_delay_env, model_dir="models\DDPG_non_corr_with_delay" , )
print('\033[1m  DDPG Non Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %% [markdown]
# # **SAC**

# %% [markdown]
# ### SAC Corr

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c4_corrective_pred_no_delay_env, model_dir="models\SAC_corr_no_delay" , )
print('\033[1m  SAC Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c6_corrective_pred_no_delay_env, model_dir="models\SAC_corr_no_delay" , )
print('\033[1m  SAC Corrective Env | No Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c4_corrective_pred_with_delay_env, model_dir="models\SAC_corr_with_delay" , )
print('\033[1m  SAC Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c6_corrective_pred_with_delay_env, model_dir="models\SAC_corr_with_delay" , )
print('\033[1m  SAC Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)

# %% [markdown]
# ### SAC Non Corr

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c4_non_corrective_pred_no_delay_env, model_dir="models\SAC_non_corr_no_delay" , )
print('\033[1m  SAC Non Corrective Env | No Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)
# Out:
# {'cut': 314, 'score': 3112569700.844474}
# Reached 314 None
# {'cut': 314, 'score': 137990.21655224383}
# Reached 314 None
# {'cut': 314, 'score': 775.1419368898694}
# Reached 314 None
# {'cut': 314, 'score': 752.0644359551527}
# Reached 314 None
# {'cut': 314, 'score': 1413.1886518223914}
# Reached 314 None
# {'cut': 314, 'score': 4077.608271693491}
# Reached 314 None
# {'cut': 314, 'score': 5563.735280104939}
# Reached 314 None
# {'cut': 314, 'score': 2650.167854361031}
# Reached 314 None
# {'cut': 314, 'score': 18460.197008886204}
# Reached 314 None
# {'cut': 314, 'score': 56417.46643741999}
# Reached 314 None
# {'cut': 314, 'score': 930617.4393712846}
# Reached 314 None
# {'cut': 314, 'score': 10779.825262203014}
# Reached 314 None
# {'cut': 314, 'score': 8146.882517553841}
# Reached 314 None
# {'cut': 314, 'score': 37683.41788745915}
# Reached 314 None
# {'cut': 314, 'score': 10887.223676039039}
# Reached 314 None
# {'cut': 314, 'score': 18547.217584952097}
# Reached 314 None
# {'cut': 314, 'score': 157325.7799572666}
# Reached 314 None
# {'cut': 314, 'score': 10045375.159293333}
# Reached 314 None
# {'cut': 314, 'score': 80892.47035136625}
# Reached 314 None
# {'cut': 314, 'score': 173280.03454724103}
# Reached 314 None
# {'cut': 314, 'score': 3553.875705965813}
# Reached 314 None
# {'cut': 314, 'score': 8223.697908263426}
# Reached 314 None
# {'cut': 314, 'score': 27769.342673275853}
# Reached 314 None
# {'cut': 314, 'score': 1532331.0009810426}
# Reached 314 None
# {'cut': 314, 'score': 22706508.527907677}
# Reached 314 None
# {'cut': 314, 'score': 10664.507978150998}
# Reached 314 None
# {'cut': 314, 'score': 5701.565948637903}
# Reached 314 None
# {'cut': 314, 'score': 88620.4344752087}
# Reached 314 None
# {'cut': 314, 'score': 3729.978910945574}
# Reached 314 None
#   SAC Non Corrective Env | No Delay | Cutter 4
#
# Max Reward is :  -643.5100530020333  and it is found at timestep :  40
# Min Phm Score is :  752.0644359551527  and it is found at timestep :  39
# Max Reward-314 is :  -643.5100530020333  and it is found at timestep :  40

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c6_non_corrective_pred_no_delay_env, model_dir="models\SAC_non_corr_no_delay" , )
print('\033[1m  SAC Non Corrective Env | No Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)
# Out:
# {'cut': 314, 'score': 32045136.559304975}
# Reached 314 None
# {'cut': 314, 'score': 1352367.9273216543}
# Reached 314 None
# {'cut': 314, 'score': 20461500.205586582}
# Reached 314 None
# {'cut': 314, 'score': 17786245.351090614}
# Reached 314 None
# {'cut': 314, 'score': 5567386285.209656}
# Reached 314 None
# {'cut': 314, 'score': 3978999.3507647435}
# Reached 314 None
# {'cut': 314, 'score': 614069410.4345366}
# Reached 314 None
# {'cut': 314, 'score': 45746.854076351774}
# Reached 314 None
# {'cut': 314, 'score': 72722.03189794697}
# Reached 314 None
# {'cut': 314, 'score': 13494197.928148177}
# Reached 314 None
# {'cut': 314, 'score': 3140.837366733796}
# Reached 314 None
# {'cut': 314, 'score': 6254.185614665357}
# Reached 314 None
# {'cut': 314, 'score': 55968.63652584469}
# Reached 314 None
# {'cut': 314, 'score': 4083.9950979990153}
# Reached 314 None
# {'cut': 314, 'score': 9725.406257603883}
# Reached 314 None
# {'cut': 314, 'score': 1249059.5136913448}
# Reached 314 None
# {'cut': 314, 'score': 13203.818128797368}
# Reached 314 None
# {'cut': 314, 'score': 140658.61824144097}
# Reached 314 None
# {'cut': 314, 'score': 34784.396645659304}
# Reached 314 None
# {'cut': 314, 'score': 137020.79808696368}
# Reached 314 None
# {'cut': 314, 'score': 527897.5738706988}
# Reached 314 None
# {'cut': 314, 'score': 28624.41481924652}
# Reached 314 None
# {'cut': 314, 'score': 71673.51244219537}
# Reached 314 None
# {'cut': 314, 'score': 4435231.335273487}
# Reached 314 None
# {'cut': 314, 'score': 240617.0818724203}
# Reached 314 None
# {'cut': 314, 'score': 13886.995296038689}
# Reached 314 None
# {'cut': 314, 'score': 68062.56230753765}
# Reached 314 None
# {'cut': 314, 'score': 115926756.47738782}
# Reached 314 None
# {'cut': 314, 'score': 10693493.226265792}
# Reached 314 None
# {'cut': 314, 'score': 769321.2035685115}
# Reached 314 None
# {'cut': 314, 'score': 117694.78161803607}
# Reached 314 None
# {'cut': 314, 'score': 5947220.2832499975}
# Reached 314 None
# {'cut': 314, 'score': 9697279.762648812}
# Reached 314 None
# {'cut': 314, 'score': 933318.818971818}
# Reached 314 None
# {'cut': 314, 'score': 21654.08223546562}
# Reached 314 None
# {'cut': 314, 'score': 294395.40351896227}
# Reached 314 None
# {'cut': 314, 'score': 73902.64847827275}
# Reached 314 None
# {'cut': 314, 'score': 193738.44894189923}
# Reached 314 None
# {'cut': 314, 'score': 2235335.4976441213}
# Reached 314 None
# {'cut': 314, 'score': 1047620.0960630219}
# Reached 314 None
#   SAC Non Corrective Env | No Delay | Cutter 6
#
# Max Reward is :  -5679.970689255203  and it is found at timestep :  41
# Min Phm Score is :  3140.837366733796  and it is found at timestep :  46
# Max Reward-314 is :  -5679.970689255203  and it is found at timestep :  41

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c4_non_corrective_pred_with_delay_env, model_dir="models\SAC_non_corr_with_delay" , )
print('\033[1m  SAC Non Corrective Env | With Delay | Cutter 4   \033[0m')
print_results(r, p, r_314)
# Out:
#   SAC Non Corrective Env | With Delay | Cutter 4
#
# Max Reward is :  -23455.729347658093  and it is found at timestep :  20
# Min Phm Score is :  11418.283896309002  and it is found at timestep :  20
# Max Reward-314 is :  -23455.729347658093  and it is found at timestep :  20

# %%
r,p,r_314 = find_314_non_corr(algo="SAC", env=c6_non_corrective_pred_with_delay_env, model_dir="models\SAC_non_corr_with_delay" , )
print('\033[1m  SAC Non Corrective Env | With Delay | Cutter 6   \033[0m')
print_results(r, p, r_314)
# Out:
#   SAC Non Corrective Env | With Delay | Cutter 6
#
# Max Reward is :  -15048.317533337558  and it is found at timestep :  47
# Min Phm Score is :  7712.814000433971  and it is found at timestep :  19
# Max Reward-314 is :  -15048.317533337558  and it is found at timestep :  47
